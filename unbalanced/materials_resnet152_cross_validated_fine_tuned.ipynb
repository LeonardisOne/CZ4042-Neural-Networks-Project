# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# set path to FMD image directory
data_dir = pathlib.Path("image")

# total no. of images in FMD dataset
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 1000

# %%
# set batch size for training
batch_size = 16

# set dimensions to change images into for training
# 299x299 images is used to train for consistency between different pre-trained models
img_height = 299
img_width = 299

# %%
# create dataset from the image directory
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*.jpg'), shuffle=False)
# shuffle the 1,000 images with the random seed value of 123 before training
list_ds = list_ds.shuffle(image_count, seed=123, reshuffle_each_iteration=False)

# %%
# get class names from the folder names in data_dir
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['fabric' 'foliage' 'glass' 'leather' 'metal' 'paper' 'plastic' 'stone'
#  'water' 'wood']

# %%
# split dataset into 5 equal sized parts for 5-fold cross validation
A = list_ds.shard(num_shards=5, index=0)
B = list_ds.shard(num_shards=5, index=1)
C = list_ds.shard(num_shards=5, index=2)
D = list_ds.shard(num_shards=5, index=3)
E = list_ds.shard(num_shards=5, index=4)

# %%
# check no. of samples in each partition is the same
print(A.cardinality().numpy())
print(B.cardinality().numpy())
print(C.cardinality().numpy())
print(D.cardinality().numpy())
print(E.cardinality().numpy())
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# prompt the tf.data runtime to tune the number of elements to prefetch dynamically at runtime
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# use the path of image to load the image into each partition of the dataset
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
A = A.map(process_path, num_parallel_calls=AUTOTUNE)
B = B.map(process_path, num_parallel_calls=AUTOTUNE)
C = C.map(process_path, num_parallel_calls=AUTOTUNE)
D = D.map(process_path, num_parallel_calls=AUTOTUNE)
E = E.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in A.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (299, 299, 3)
# Label:  1

# %%
# shuffle, batch, and prefetch the dataset
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
# map the dataset partitions to integers for building training/test sets during cross-validation
ds_fold_dict = {0:A, 1:B, 2:C, 3:D, 4:E}

# %%
# normalise the input values to the pre-trained model's required range of values
preprocess_input = keras.applications.resnet_v2.preprocess_input

# %%
# set a low learning rate to avoid overfitting too quickly
base_learning_rate = 0.0001

# create the model to train using the pre-trained model as base model
def create_model(base_model):
  # generate additional training data from input training data by augmenting them using random flip, rotation & zoom
  data_augmentation = keras.Sequential(
    [
      layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                  input_shape=(img_height, 
                                                                img_width,
                                                                3)),
      layers.experimental.preprocessing.RandomRotation(0.1),
      layers.experimental.preprocessing.RandomZoom(0.1),
    ]
  )

  # average over the spatial locations to convert the features to a single vector per image
  global_average_layer = keras.layers.GlobalAveragePooling2D()
  # convert these features into a single prediction per image
  prediction_layer = keras.layers.Dense(10)

  # Build a model by chaining together the layers using the Keras Functional API.
  inputs = keras.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = preprocess_input(x)
  x = base_model(x, training=False) # use training=False as the base model contains a BatchNormalization layer
  x = global_average_layer(x)
  x = keras.layers.Dropout(0.2)(x) # add dropout to fully connected layer to reduce overfitting
  outputs = prediction_layer(x)
  model = keras.Model(inputs, outputs)
  optimizer = keras.optimizers.Adam(lr=base_learning_rate)
  loss= keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  # compile model with Adam optimizer with specified learning rate
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  model.summary()
  return model

# %%
no_epochs = 50
fine_tune_epochs = 20
total_epochs =  no_epochs + fine_tune_epochs
# Fine-tune from this layer onwards
fine_tune_at = -27

# %%
# store results to plot graphs and get cross-validated accuracies
history_map = {}
base_model_acc_list = []
pre_trained_acc_list = []
final_acc_list = []

# do 5-fold cross-validation
for i in range(5):
  print('fold', i + 1)
  temp_dict = ds_fold_dict.copy()
  # get test set for this iteration
  current_val_ds = temp_dict[i]

  # get training set for this iteration from remaining data samples
  del temp_dict[i]
  current_train_ds = None
  for ds_shard in temp_dict.values():
    if current_train_ds is None:
      current_train_ds = ds_shard
    else:
      current_train_ds = current_train_ds.concatenate(ds_shard)
  
  # configure both training and test sets to improve performance
  current_train_ds = configure_for_performance(current_train_ds)
  current_val_ds = configure_for_performance(current_val_ds)

  # get pre-trained model
  base_model = keras.applications.ResNet152V2(include_top=False, input_shape=(img_height, img_width, 3))
  # don't train base model weights
  base_model.trainable = False

  # create a new model
  model = create_model(base_model)
  # get initial test accuracy
  base_model_acc_list.append(model.evaluate(current_val_ds)[1])
  # train for specified epochs
  history = model.fit(current_train_ds,
                    epochs=no_epochs,
                    validation_data=current_val_ds)
  
  # get test accuracy before fine-tuning
  pre_trained_acc_list.append(model.evaluate(current_val_ds)[1])

  # start fine-tuning by setting base model to be trainable
  base_model.trainable = True

  # Freeze all the layers before the `fine_tune_at` layer to only fine-tune top layer(s)
  for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False

  # compile model again with RMSProp optimizer with even smaller learning rate to reduce overfitting
  optimizer = keras.optimizers.RMSprop(lr=base_learning_rate/10)
  loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  print('Fine-tuned model:')
  model.summary()

  # train fine-tuned model
  history_fine = model.fit(current_train_ds,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=current_val_ds)

  # save results
  if i == 0:
    history_map['accuracy'] = [history.history['accuracy'] + history_fine.history['accuracy']]
    history_map['val_accuracy'] = [history.history['val_accuracy'] + history_fine.history['val_accuracy']]
    history_map['loss'] = [history.history['loss'] + history_fine.history['loss']]
    history_map['val_loss'] = [history.history['val_loss'] + history_fine.history['val_loss']]
  else:
    history_map['accuracy'].append(history.history['accuracy'] + history_fine.history['accuracy'])
    history_map['val_accuracy'].append(history.history['val_accuracy'] + history_fine.history['val_accuracy'])
    history_map['loss'].append(history.history['loss'] + history_fine.history['loss'])
    history_map['val_loss'].append(history.history['val_loss'] + history_fine.history['val_loss'])
  
  # get final test accuracy by taking the max accuracy over the whole training due to potential overfitting at end of fine-tuning
  final_acc_list.append(np.amax(history.history['val_accuracy'] + history_fine.history['val_accuracy']))
# Out:
# ===================] - 7s 150ms/step - loss: 0.3979 - accuracy: 0.8825 - val_loss: 0.5794 - val_accuracy: 0.8300
# Epoch 36/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.4012 - accuracy: 0.8900 - val_loss: 0.5745 - val_accuracy: 0.8400
# Epoch 37/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3604 - accuracy: 0.9100 - val_loss: 0.5715 - val_accuracy: 0.8350
# Epoch 38/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.3829 - accuracy: 0.9038 - val_loss: 0.5621 - val_accuracy: 0.8500
# Epoch 39/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3638 - accuracy: 0.9087 - val_loss: 0.5620 - val_accuracy: 0.8400
# Epoch 40/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.3481 - accuracy: 0.9150 - val_loss: 0.5559 - val_accuracy: 0.8400
# Epoch 41/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3584 - accuracy: 0.9050 - val_loss: 0.5563 - val_accuracy: 0.8350
# Epoch 42/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3340 - accuracy: 0.9200 - val_loss: 0.5528 - val_accuracy: 0.8400
# Epoch 43/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.3285 - accuracy: 0.9150 - val_loss: 0.5527 - val_accuracy: 0.8350
# Epoch 44/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3121 - accuracy: 0.9262 - val_loss: 0.5579 - val_accuracy: 0.8350
# Epoch 45/50
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3138 - accuracy: 0.9287 - val_loss: 0.5465 - val_accuracy: 0.8400
# Epoch 46/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.3072 - accuracy: 0.9237 - val_loss: 0.5406 - val_accuracy: 0.8400
# Epoch 47/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3128 - accuracy: 0.9137 - val_loss: 0.5334 - val_accuracy: 0.8400
# Epoch 48/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.2878 - accuracy: 0.9300 - val_loss: 0.5349 - val_accuracy: 0.8400
# Epoch 49/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.2878 - accuracy: 0.9300 - val_loss: 0.5387 - val_accuracy: 0.8400
# Epoch 50/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.2943 - accuracy: 0.9337 - val_loss: 0.5378 - val_accuracy: 0.8400
# 13/13 [==============================] - 1s 108ms/step - loss: 0.5378 - accuracy: 0.8400
# Fine-tuned model:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_3 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# resnet152v2 (Functional)     (None, 10, 10, 2048)      58331648
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 58,352,138
# Trainable params: 12,103,690
# Non-trainable params: 46,248,448
# _________________________________________________________________
# Epoch 50/70
# 50/50 [==============================] - 10s 205ms/step - loss: 0.2719 - accuracy: 0.9013 - val_loss: 0.5202 - val_accuracy: 0.8500
# Epoch 51/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.1888 - accuracy: 0.9438 - val_loss: 0.5493 - val_accuracy: 0.8600
# Epoch 52/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.1271 - accuracy: 0.9563 - val_loss: 0.6198 - val_accuracy: 0.8450
# Epoch 53/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.1228 - accuracy: 0.9575 - val_loss: 0.6219 - val_accuracy: 0.8550
# Epoch 54/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0879 - accuracy: 0.9675 - val_loss: 0.6624 - val_accuracy: 0.8450
# Epoch 55/70
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0630 - accuracy: 0.9825 - val_loss: 0.7356 - val_accuracy: 0.8050
# Epoch 56/70
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0766 - accuracy: 0.9737 - val_loss: 0.7045 - val_accuracy: 0.8250
# Epoch 57/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0551 - accuracy: 0.9837 - val_loss: 0.8539 - val_accuracy: 0.8150
# Epoch 58/70
# 50/50 [==============================] - 9s 170ms/step - loss: 0.0493 - accuracy: 0.9837 - val_loss: 0.7582 - val_accuracy: 0.8550
# Epoch 59/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.0362 - accuracy: 0.9862 - val_loss: 0.7014 - val_accuracy: 0.8400
# Epoch 60/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.0373 - accuracy: 0.9875 - val_loss: 0.8174 - val_accuracy: 0.8200
# Epoch 61/70
# 50/50 [==============================] - 9s 170ms/step - loss: 0.0404 - accuracy: 0.9875 - val_loss: 0.7796 - val_accuracy: 0.8400
# Epoch 62/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 0.7796 - val_accuracy: 0.8300
# Epoch 63/70
# 50/50 [==============================] - 9s 170ms/step - loss: 0.0265 - accuracy: 0.9912 - val_loss: 0.8057 - val_accuracy: 0.8400
# Epoch 64/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.8251 - val_accuracy: 0.8500
# Epoch 65/70
# 50/50 [==============================] - 9s 170ms/step - loss: 0.0262 - accuracy: 0.9912 - val_loss: 0.9339 - val_accuracy: 0.8450
# Epoch 66/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0151 - accuracy: 0.9975 - val_loss: 0.8695 - val_accuracy: 0.8300
# Epoch 67/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0211 - accuracy: 0.9950 - val_loss: 0.9133 - val_accuracy: 0.8150
# Epoch 68/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0305 - accuracy: 0.9912 - val_loss: 0.9197 - val_accuracy: 0.8200
# Epoch 69/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0228 - accuracy: 0.9912 - val_loss: 0.8484 - val_accuracy: 0.8250
# Epoch 70/70
# 50/50 [==============================] - 8s 170ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.9159 - val_accuracy: 0.8250
# fold 5
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# resnet152v2 (Functional)     (None, 10, 10, 2048)      58331648
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 58,352,138
# Trainable params: 20,490
# Non-trainable params: 58,331,648
# _________________________________________________________________
# 13/13 [==============================] - 1s 105ms/step - loss: 2.4309 - accuracy: 0.1450
# Epoch 1/50
# 50/50 [==============================] - 7s 147ms/step - loss: 2.4949 - accuracy: 0.1725 - val_loss: 2.0845 - val_accuracy: 0.2700
# Epoch 2/50
# 50/50 [==============================] - 7s 147ms/step - loss: 2.1254 - accuracy: 0.2738 - val_loss: 1.8415 - val_accuracy: 0.3800
# Epoch 3/50
# 50/50 [==============================] - 7s 148ms/step - loss: 1.8891 - accuracy: 0.3512 - val_loss: 1.6482 - val_accuracy: 0.4600
# Epoch 4/50
# 50/50 [==============================] - 7s 148ms/step - loss: 1.7102 - accuracy: 0.4350 - val_loss: 1.4791 - val_accuracy: 0.5450
# Epoch 5/50
# 50/50 [==============================] - 7s 148ms/step - loss: 1.5466 - accuracy: 0.4837 - val_loss: 1.3485 - val_accuracy: 0.6150
# Epoch 6/50
# 50/50 [==============================] - 7s 149ms/step - loss: 1.3684 - accuracy: 0.5775 - val_loss: 1.2485 - val_accuracy: 0.6550
# Epoch 7/50
# 50/50 [==============================] - 7s 148ms/step - loss: 1.2913 - accuracy: 0.6100 - val_loss: 1.1544 - val_accuracy: 0.6800
# Epoch 8/50
# 50/50 [==============================] - 7s 149ms/step - loss: 1.1673 - accuracy: 0.6450 - val_loss: 1.0787 - val_accuracy: 0.6800
# Epoch 9/50
# 50/50 [==============================] - 7s 150ms/step - loss: 1.1453 - accuracy: 0.6375 - val_loss: 1.0164 - val_accuracy: 0.7050
# Epoch 10/50
# 50/50 [==============================] - 7s 150ms/step - loss: 1.0504 - accuracy: 0.6913 - val_loss: 0.9647 - val_accuracy: 0.7100
# Epoch 11/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.9574 - accuracy: 0.7450 - val_loss: 0.9212 - val_accuracy: 0.7100
# Epoch 12/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.8844 - accuracy: 0.7525 - val_loss: 0.8811 - val_accuracy: 0.7300
# Epoch 13/50
# 50/50 [==============================] - 7s 150ms/step - loss: 0.8555 - accuracy: 0.7700 - val_loss: 0.8486 - val_accuracy: 0.7500
# Epoch 14/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.8058 - accuracy: 0.7625 - val_loss: 0.8181 - val_accuracy: 0.7600
# Epoch 15/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.7690 - accuracy: 0.7775 - val_loss: 0.7910 - val_accuracy: 0.7600
# Epoch 16/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.7330 - accuracy: 0.7887 - val_loss: 0.7664 - val_accuracy: 0.7700
# Epoch 17/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.7098 - accuracy: 0.8012 - val_loss: 0.7509 - val_accuracy: 0.7800
# Epoch 18/50
# 50/50 [==============================] - 7s 150ms/step - loss: 0.6845 - accuracy: 0.8025 - val_loss: 0.7278 - val_accuracy: 0.7900
# Epoch 19/50
# 50/50 [==============================] - 7s 150ms/step - loss: 0.6520 - accuracy: 0.8175 - val_loss: 0.7097 - val_accuracy: 0.7850
# Epoch 20/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.6532 - accuracy: 0.8188 - val_loss: 0.7004 - val_accuracy: 0.7800
# Epoch 21/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.6069 - accuracy: 0.8413 - val_loss: 0.6837 - val_accuracy: 0.7850
# Epoch 22/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.6087 - accuracy: 0.8225 - val_loss: 0.6660 - val_accuracy: 0.7900
# Epoch 23/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.5554 - accuracy: 0.8600 - val_loss: 0.6557 - val_accuracy: 0.8050
# Epoch 24/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.5543 - accuracy: 0.8500 - val_loss: 0.6447 - val_accuracy: 0.7950
# Epoch 25/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.5621 - accuracy: 0.8500 - val_loss: 0.6323 - val_accuracy: 0.8150
# Epoch 26/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.5231 - accuracy: 0.8562 - val_loss: 0.6216 - val_accuracy: 0.8200
# Epoch 27/50
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4884 - accuracy: 0.8725 - val_loss: 0.6145 - val_accuracy: 0.8150
# Epoch 28/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.4905 - accuracy: 0.8675 - val_loss: 0.6043 - val_accuracy: 0.8150
# Epoch 29/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.4763 - accuracy: 0.8725 - val_loss: 0.5955 - val_accuracy: 0.8150
# Epoch 30/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4554 - accuracy: 0.8838 - val_loss: 0.5863 - val_accuracy: 0.8200
# Epoch 31/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4420 - accuracy: 0.8838 - val_loss: 0.5866 - val_accuracy: 0.8200
# Epoch 32/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.4566 - accuracy: 0.8788 - val_loss: 0.5770 - val_accuracy: 0.8000
# Epoch 33/50
# 50/50 [==============================] - 7s 150ms/step - loss: 0.4489 - accuracy: 0.8725 - val_loss: 0.5705 - val_accuracy: 0.8050
# Epoch 34/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4220 - accuracy: 0.8800 - val_loss: 0.5649 - val_accuracy: 0.8200
# Epoch 35/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.4024 - accuracy: 0.8900 - val_loss: 0.5552 - val_accuracy: 0.8150
# Epoch 36/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.4224 - accuracy: 0.8763 - val_loss: 0.5458 - val_accuracy: 0.8200
# Epoch 37/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3978 - accuracy: 0.9025 - val_loss: 0.5476 - val_accuracy: 0.8100
# Epoch 38/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3797 - accuracy: 0.9050 - val_loss: 0.5370 - val_accuracy: 0.8100
# Epoch 39/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3568 - accuracy: 0.9000 - val_loss: 0.5326 - val_accuracy: 0.8150
# Epoch 40/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.3615 - accuracy: 0.9125 - val_loss: 0.5291 - val_accuracy: 0.8250
# Epoch 41/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3660 - accuracy: 0.8913 - val_loss: 0.5290 - val_accuracy: 0.8100
# Epoch 42/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3535 - accuracy: 0.9038 - val_loss: 0.5240 - val_accuracy: 0.8200
# Epoch 43/50
# 50/50 [==============================] - 7s 150ms/step - loss: 0.3591 - accuracy: 0.9112 - val_loss: 0.5195 - val_accuracy: 0.8200
# Epoch 44/50
# 50/50 [==============================] - 7s 149ms/step - loss: 0.3417 - accuracy: 0.9150 - val_loss: 0.5193 - val_accuracy: 0.8200
# Epoch 45/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3290 - accuracy: 0.9175 - val_loss: 0.5181 - val_accuracy: 0.8150
# Epoch 46/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.3282 - accuracy: 0.9062 - val_loss: 0.5131 - val_accuracy: 0.8150
# Epoch 47/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3204 - accuracy: 0.9187 - val_loss: 0.5085 - val_accuracy: 0.8150
# Epoch 48/50
# 50/50 [==============================] - 8s 150ms/step - loss: 0.3084 - accuracy: 0.9250 - val_loss: 0.5063 - val_accuracy: 0.8200
# Epoch 49/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3126 - accuracy: 0.9237 - val_loss: 0.5070 - val_accuracy: 0.8200
# Epoch 50/50
# 50/50 [==============================] - 8s 151ms/step - loss: 0.3027 - accuracy: 0.9262 - val_loss: 0.5028 - val_accuracy: 0.8200
# 13/13 [==============================] - 1s 108ms/step - loss: 0.5028 - accuracy: 0.8200
# Fine-tuned model:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# resnet152v2 (Functional)     (None, 10, 10, 2048)      58331648
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 58,352,138
# Trainable params: 12,103,690
# Non-trainable params: 46,248,448
# _________________________________________________________________
# Epoch 50/70
# 50/50 [==============================] - 10s 206ms/step - loss: 0.2591 - accuracy: 0.9175 - val_loss: 0.4711 - val_accuracy: 0.8200
# Epoch 51/70
# 50/50 [==============================] - 8s 168ms/step - loss: 0.2092 - accuracy: 0.9275 - val_loss: 0.4876 - val_accuracy: 0.8250
# Epoch 52/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.1722 - accuracy: 0.9425 - val_loss: 0.4785 - val_accuracy: 0.8350
# Epoch 53/70
# 50/50 [==============================] - 8s 170ms/step - loss: 0.1238 - accuracy: 0.9588 - val_loss: 0.5396 - val_accuracy: 0.8350
# Epoch 54/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.1227 - accuracy: 0.9538 - val_loss: 0.5202 - val_accuracy: 0.8300
# Epoch 55/70
# 50/50 [==============================] - 8s 168ms/step - loss: 0.0943 - accuracy: 0.9675 - val_loss: 0.5316 - val_accuracy: 0.8250
# Epoch 56/70
# 50/50 [==============================] - 8s 169ms/step - loss: 0.0835 - accuracy: 0.9762 - val_loss: 0.5690 - val_accuracy: 0.8150
# Epoch 57/70
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0617 - accuracy: 0.9800 - val_loss: 0.6001 - val_accuracy: 0.8200
# Epoch 58/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0563 - accuracy: 0.9850 - val_loss: 0.6093 - val_accuracy: 0.8200
# Epoch 59/70
# 50/50 [==============================] - 9s 173ms/step - loss: 0.0460 - accuracy: 0.9837 - val_loss: 0.6127 - val_accuracy: 0.8400
# Epoch 60/70
# 50/50 [==============================] - 9s 172ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.6066 - val_accuracy: 0.8400
# Epoch 61/70
# 50/50 [==============================] - 9s 175ms/step - loss: 0.0409 - accuracy: 0.9862 - val_loss: 0.6393 - val_accuracy: 0.8300
# Epoch 62/70
# 50/50 [==============================] - 9s 178ms/step - loss: 0.0477 - accuracy: 0.9862 - val_loss: 0.6003 - val_accuracy: 0.8150
# Epoch 63/70
# 50/50 [==============================] - 9s 174ms/step - loss: 0.0314 - accuracy: 0.9887 - val_loss: 0.7327 - val_accuracy: 0.8300
# Epoch 64/70
# 50/50 [==============================] - 8s 170ms/step - loss: 0.0266 - accuracy: 0.9912 - val_loss: 0.6639 - val_accuracy: 0.8350
# Epoch 65/70
# 50/50 [==============================] - 9s 170ms/step - loss: 0.0219 - accuracy: 0.9975 - val_loss: 0.7191 - val_accuracy: 0.8350
# Epoch 66/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0310 - accuracy: 0.9912 - val_loss: 0.6171 - val_accuracy: 0.8450
# Epoch 67/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0132 - accuracy: 0.9962 - val_loss: 0.6817 - val_accuracy: 0.8400
# Epoch 68/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.7401 - val_accuracy: 0.8400
# Epoch 69/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0284 - accuracy: 0.9900 - val_loss: 0.7202 - val_accuracy: 0.8300
# Epoch 70/70
# 50/50 [==============================] - 9s 171ms/step - loss: 0.0232 - accuracy: 0.9887 - val_loss: 0.7259 - val_accuracy: 0.8400

# %%
# cross-validated accuracy for pre-trained model before training
print("Base model accuracy:", np.mean(base_model_acc_list))
# cross-validated accuracy before fine-tuning
print("Accuracy before fine-tuning:", np.mean(pre_trained_acc_list))
# cross-validated accuracy after fine-tuning
print("Final accuracy:", np.mean(final_acc_list))
# Out:
# Base model accuracy: 0.12899999767541886
# Accuracy before fine-tuning: 0.8179999947547912
# Final accuracy: 0.8540000081062317

# %%
# plot graph of cross-validated accuracies
acc = np.mean(history_map['accuracy'], axis=0)
val_acc = np.mean(history_map['val_accuracy'], axis=0)

plt.figure(1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.plot([no_epochs-1,no_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# plot graph of cross-validated losses
loss = np.mean(history_map['loss'], axis=0)
val_loss = np.mean(history_map['val_loss'], axis=0)

plt.figure(2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.plot([no_epochs-1,no_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
