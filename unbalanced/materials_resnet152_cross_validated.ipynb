# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# set path to FMD image directory
data_dir = pathlib.Path("image")

# total no. of images in FMD dataset
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 1000

# %%
# set batch size for training
batch_size = 16

# set dimensions to change images into for training
# 299x299 images is used to train for consistency between different pre-trained models
img_height = 299
img_width = 299

# %%
# create dataset from the image directory
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*.jpg'), shuffle=False)
# shuffle the 1,000 images with the random seed value of 123 before training
list_ds = list_ds.shuffle(image_count, seed=123, reshuffle_each_iteration=False)

# %%
# get class names from the folder names in data_dir
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['fabric' 'foliage' 'glass' 'leather' 'metal' 'paper' 'plastic' 'stone'
#  'water' 'wood']

# %%
# split dataset into 5 equal sized parts for 5-fold cross validation
A = list_ds.shard(num_shards=5, index=0)
B = list_ds.shard(num_shards=5, index=1)
C = list_ds.shard(num_shards=5, index=2)
D = list_ds.shard(num_shards=5, index=3)
E = list_ds.shard(num_shards=5, index=4)

# %%
# check no. of samples in each partition is the same
print(A.cardinality().numpy())
print(B.cardinality().numpy())
print(C.cardinality().numpy())
print(D.cardinality().numpy())
print(E.cardinality().numpy())
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# prompt the tf.data runtime to tune the number of elements to prefetch dynamically at runtime
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# use the path of image to load the image into each partition of the dataset
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
A = A.map(process_path, num_parallel_calls=AUTOTUNE)
B = B.map(process_path, num_parallel_calls=AUTOTUNE)
C = C.map(process_path, num_parallel_calls=AUTOTUNE)
D = D.map(process_path, num_parallel_calls=AUTOTUNE)
E = E.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in A.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (299, 299, 3)
# Label:  1

# %%
# shuffle, batch, and prefetch the dataset
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
# map the dataset partitions to integers for building training/test sets during cross-validation
ds_fold_dict = {0:A, 1:B, 2:C, 3:D, 4:E}

# %%
# normalise the input values to the pre-trained model's required range of values
preprocess_input = keras.applications.resnet_v2.preprocess_input

# %%
# get pre-trained model
base_model = keras.applications.ResNet152V2(include_top=False, input_shape=(img_height, img_width, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234553344/234545216 [==============================] - 9s 0us/step

# %%
# don't train base model weights
base_model.trainable = False

# %%
base_model.summary()
# Out:
# 31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block31_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block31_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block31_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block31_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block31_out (Add)         (None, 19, 19, 1024) 0           conv4_block30_out[0][0]
#                                                                  conv4_block31_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block32_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block31_out[0][0]
# __________________________________________________________________________________________________
# conv4_block32_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block32_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block32_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block32_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block32_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block32_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block32_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block32_2_conv (Conv2D)   (None, 19, 19, 256)  589824      conv4_block32_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block32_2_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block32_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block32_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block32_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block32_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block32_out (Add)         (None, 19, 19, 1024) 0           conv4_block31_out[0][0]
#                                                                  conv4_block32_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block32_out[0][0]
# __________________________________________________________________________________________________
# conv4_block33_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block33_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block33_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block33_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block33_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block33_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_conv (Conv2D)   (None, 19, 19, 256)  589824      conv4_block33_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block33_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block33_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block33_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_out (Add)         (None, 19, 19, 1024) 0           conv4_block32_out[0][0]
#                                                                  conv4_block33_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block33_out[0][0]
# __________________________________________________________________________________________________
# conv4_block34_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block34_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block34_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block34_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block34_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block34_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_conv (Conv2D)   (None, 19, 19, 256)  589824      conv4_block34_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block34_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block34_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block34_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_out (Add)         (None, 19, 19, 1024) 0           conv4_block33_out[0][0]
#                                                                  conv4_block34_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block34_out[0][0]
# __________________________________________________________________________________________________
# conv4_block35_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block35_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block35_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block35_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block35_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block35_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_conv (Conv2D)   (None, 19, 19, 256)  589824      conv4_block35_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block35_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block35_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block35_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_out (Add)         (None, 19, 19, 1024) 0           conv4_block34_out[0][0]
#                                                                  conv4_block35_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block36_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block36_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block36_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block36_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block36_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_conv (Conv2D)   (None, 10, 10, 256)  589824      conv4_block36_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block36_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block36_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 10, 10, 1024) 0           conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block36_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_out (Add)         (None, 10, 10, 1024) 0           max_pooling2d_2[0][0]
#                                                                  conv4_block36_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block36_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 10, 10, 1024) 0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 10, 10, 512)  524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 10, 10, 512)  0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 12, 12, 512)  0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 10, 10, 512)  2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 10, 10, 512)  0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 10, 10, 2048) 2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 10, 10, 2048) 0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 10, 10, 2048) 8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 10, 10, 2048) 0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 10, 10, 512)  1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 10, 10, 512)  0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 12, 12, 512)  0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 10, 10, 512)  2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 10, 10, 512)  0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 10, 10, 2048) 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 10, 10, 2048) 8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 10, 10, 2048) 0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 10, 10, 512)  1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 10, 10, 512)  0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 12, 12, 512)  0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 10, 10, 512)  2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 10, 10, 512)  0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 10, 10, 2048) 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 10, 10, 2048) 8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 10, 10, 2048) 0           post_bn[0][0]
# ==================================================================================================
# Total params: 58,331,648
# Trainable params: 0
# Non-trainable params: 58,331,648
# __________________________________________________________________________________________________

# %%
# set a low learning rate to avoid overfitting too quickly
base_learning_rate = 0.0001

# create the model to train using the pre-trained model as base model
def create_model():
  # generate additional training data from input training data by augmenting them using random flip, rotation & zoom
  data_augmentation = keras.Sequential(
    [
      layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                  input_shape=(img_height, 
                                                                img_width,
                                                                3)),
      layers.experimental.preprocessing.RandomRotation(0.1),
      layers.experimental.preprocessing.RandomZoom(0.1),
    ]
  )

  # average over the spatial locations to convert the features to a single vector per image
  global_average_layer = keras.layers.GlobalAveragePooling2D()
  # convert these features into a single prediction per image
  prediction_layer = keras.layers.Dense(10)

  # Build a model by chaining together the layers using the Keras Functional API.
  inputs = keras.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = preprocess_input(x)
  x = base_model(x, training=False) # use training=False as the base model contains a BatchNormalization layer
  x = global_average_layer(x)
  x = keras.layers.Dropout(0.2)(x) # add dropout to fully connected layer to reduce overfitting
  outputs = prediction_layer(x)
  model = keras.Model(inputs, outputs)
  optimizer = keras.optimizers.Adam(lr=base_learning_rate)
  loss= keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  # compile model with Adam optimizer with specified learning rate
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  model.summary()
  return model

# %%
no_epochs = 100

# %%
# store results to plot graphs and get cross-validated accuracies
history_map = {}
base_model_acc_list = []
final_acc_list = []

# do 5-fold cross-validation
for i in range(5):
  print('fold', i + 1)
  temp_dict = ds_fold_dict.copy()
  # get test set for this iteration
  current_val_ds = temp_dict[i]

  # get training set for this iteration from remaining data samples
  del temp_dict[i]
  current_train_ds = None
  for ds_shard in temp_dict.values():
    if current_train_ds is None:
      current_train_ds = ds_shard
    else:
      current_train_ds = current_train_ds.concatenate(ds_shard)
  
  # configure both training and test sets to improve performance
  current_train_ds = configure_for_performance(current_train_ds)
  current_val_ds = configure_for_performance(current_val_ds)

  # create a new model
  model = create_model()
  # get initial test accuracy
  base_model_acc_list.append(model.evaluate(current_val_ds)[1])
  # train for specified epochs
  history = model.fit(current_train_ds,
                    epochs=no_epochs,
                    validation_data=current_val_ds)
  
  # save results
  if i == 0:
    history_map['accuracy'] = [history.history['accuracy']]
    history_map['val_accuracy'] = [history.history['val_accuracy']]
    history_map['loss'] = [history.history['loss']]
    history_map['val_loss'] = [history.history['val_loss']]
  else:
    history_map['accuracy'].append(history.history['accuracy'])
    history_map['val_accuracy'].append(history.history['val_accuracy'])
    history_map['loss'].append(history.history['loss'])
    history_map['val_loss'].append(history.history['val_loss'])
  
  # get final test accuracy by taking the max accuracy over the whole training
  final_acc_list.append(np.amax(history.history['val_accuracy']))
# Out:
#  val_accuracy: 0.8350
# Epoch 73/100
# 50/50 [==============================] - 14s 276ms/step - loss: 0.1972 - accuracy: 0.9563 - val_loss: 0.5198 - val_accuracy: 0.8300
# Epoch 74/100
# 50/50 [==============================] - 13s 262ms/step - loss: 0.1858 - accuracy: 0.9563 - val_loss: 0.5303 - val_accuracy: 0.8250
# Epoch 75/100
# 50/50 [==============================] - 14s 277ms/step - loss: 0.1945 - accuracy: 0.9550 - val_loss: 0.5221 - val_accuracy: 0.8300
# Epoch 76/100
# 50/50 [==============================] - 12s 248ms/step - loss: 0.1889 - accuracy: 0.9600 - val_loss: 0.5202 - val_accuracy: 0.8400
# Epoch 77/100
# 50/50 [==============================] - 13s 270ms/step - loss: 0.1759 - accuracy: 0.9563 - val_loss: 0.5242 - val_accuracy: 0.8400
# Epoch 78/100
# 50/50 [==============================] - 13s 258ms/step - loss: 0.1808 - accuracy: 0.9650 - val_loss: 0.5284 - val_accuracy: 0.8250
# Epoch 79/100
# 50/50 [==============================] - 13s 253ms/step - loss: 0.1928 - accuracy: 0.9563 - val_loss: 0.5264 - val_accuracy: 0.8300
# Epoch 80/100
# 50/50 [==============================] - 13s 253ms/step - loss: 0.1904 - accuracy: 0.9600 - val_loss: 0.5177 - val_accuracy: 0.8400
# Epoch 81/100
# 50/50 [==============================] - 13s 251ms/step - loss: 0.1918 - accuracy: 0.9575 - val_loss: 0.5161 - val_accuracy: 0.8400
# Epoch 82/100
# 50/50 [==============================] - 11s 229ms/step - loss: 0.1739 - accuracy: 0.9575 - val_loss: 0.5186 - val_accuracy: 0.8400
# Epoch 83/100
# 50/50 [==============================] - 11s 230ms/step - loss: 0.1773 - accuracy: 0.9675 - val_loss: 0.5158 - val_accuracy: 0.8350
# Epoch 84/100
# 50/50 [==============================] - 11s 226ms/step - loss: 0.1652 - accuracy: 0.9737 - val_loss: 0.5154 - val_accuracy: 0.8400
# Epoch 85/100
# 50/50 [==============================] - 11s 229ms/step - loss: 0.1658 - accuracy: 0.9663 - val_loss: 0.5153 - val_accuracy: 0.8400
# Epoch 86/100
# 50/50 [==============================] - 12s 240ms/step - loss: 0.1681 - accuracy: 0.9700 - val_loss: 0.5111 - val_accuracy: 0.8450
# Epoch 87/100
# 50/50 [==============================] - 12s 246ms/step - loss: 0.1669 - accuracy: 0.9613 - val_loss: 0.5088 - val_accuracy: 0.8450
# Epoch 88/100
# 50/50 [==============================] - 13s 262ms/step - loss: 0.1554 - accuracy: 0.9737 - val_loss: 0.5192 - val_accuracy: 0.8350
# Epoch 89/100
# 50/50 [==============================] - 15s 293ms/step - loss: 0.1653 - accuracy: 0.9650 - val_loss: 0.5230 - val_accuracy: 0.8400
# Epoch 90/100
# 50/50 [==============================] - 13s 267ms/step - loss: 0.1724 - accuracy: 0.9600 - val_loss: 0.5119 - val_accuracy: 0.8350
# Epoch 91/100
# 50/50 [==============================] - 12s 233ms/step - loss: 0.1582 - accuracy: 0.9700 - val_loss: 0.5204 - val_accuracy: 0.8200
# Epoch 92/100
# 50/50 [==============================] - 11s 212ms/step - loss: 0.1471 - accuracy: 0.9762 - val_loss: 0.5167 - val_accuracy: 0.8350
# Epoch 93/100
# 50/50 [==============================] - 11s 211ms/step - loss: 0.1557 - accuracy: 0.9650 - val_loss: 0.5195 - val_accuracy: 0.8350
# Epoch 94/100
# 50/50 [==============================] - 11s 216ms/step - loss: 0.1461 - accuracy: 0.9712 - val_loss: 0.5267 - val_accuracy: 0.8400
# Epoch 95/100
# 50/50 [==============================] - 12s 243ms/step - loss: 0.1438 - accuracy: 0.9700 - val_loss: 0.5284 - val_accuracy: 0.8350
# Epoch 96/100
# 50/50 [==============================] - 11s 217ms/step - loss: 0.1441 - accuracy: 0.9725 - val_loss: 0.5216 - val_accuracy: 0.8300
# Epoch 97/100
# 50/50 [==============================] - 11s 216ms/step - loss: 0.1430 - accuracy: 0.9787 - val_loss: 0.5213 - val_accuracy: 0.8400
# Epoch 98/100
# 50/50 [==============================] - 11s 228ms/step - loss: 0.1298 - accuracy: 0.9800 - val_loss: 0.5232 - val_accuracy: 0.8300
# Epoch 99/100
# 50/50 [==============================] - 12s 236ms/step - loss: 0.1528 - accuracy: 0.9688 - val_loss: 0.5251 - val_accuracy: 0.8350
# Epoch 100/100
# 50/50 [==============================] - 12s 234ms/step - loss: 0.1453 - accuracy: 0.9650 - val_loss: 0.5231 - val_accuracy: 0.8350
# fold 5
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# resnet152v2 (Functional)     (None, 10, 10, 2048)      58331648
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 58,352,138
# Trainable params: 20,490
# Non-trainable params: 58,331,648
# _________________________________________________________________
# 13/13 [==============================] - 2s 179ms/step - loss: 2.5704 - accuracy: 0.0850
# Epoch 1/100
# 50/50 [==============================] - 13s 262ms/step - loss: 2.5346 - accuracy: 0.1312 - val_loss: 2.1989 - val_accuracy: 0.1550
# Epoch 2/100
# 50/50 [==============================] - 11s 217ms/step - loss: 2.2333 - accuracy: 0.2050 - val_loss: 1.9334 - val_accuracy: 0.2500
# Epoch 3/100
# 50/50 [==============================] - 12s 236ms/step - loss: 1.9133 - accuracy: 0.3288 - val_loss: 1.7203 - val_accuracy: 0.3700
# Epoch 4/100
# 50/50 [==============================] - 13s 258ms/step - loss: 1.7392 - accuracy: 0.4038 - val_loss: 1.5394 - val_accuracy: 0.5200
# Epoch 5/100
# 50/50 [==============================] - 9s 189ms/step - loss: 1.5372 - accuracy: 0.5175 - val_loss: 1.3942 - val_accuracy: 0.5850
# Epoch 6/100
# 50/50 [==============================] - 8s 163ms/step - loss: 1.3939 - accuracy: 0.5575 - val_loss: 1.2712 - val_accuracy: 0.6450
# Epoch 7/100
# 50/50 [==============================] - 8s 155ms/step - loss: 1.3013 - accuracy: 0.6112 - val_loss: 1.1737 - val_accuracy: 0.6900
# Epoch 8/100
# 50/50 [==============================] - 8s 155ms/step - loss: 1.1976 - accuracy: 0.6413 - val_loss: 1.0860 - val_accuracy: 0.7250
# Epoch 9/100
# 50/50 [==============================] - 8s 158ms/step - loss: 1.1284 - accuracy: 0.6750 - val_loss: 1.0220 - val_accuracy: 0.7500
# Epoch 10/100
# 50/50 [==============================] - 8s 163ms/step - loss: 1.0253 - accuracy: 0.7163 - val_loss: 0.9652 - val_accuracy: 0.7600
# Epoch 11/100
# 50/50 [==============================] - 8s 157ms/step - loss: 0.9686 - accuracy: 0.7163 - val_loss: 0.9139 - val_accuracy: 0.7750
# Epoch 12/100
# 50/50 [==============================] - 8s 155ms/step - loss: 0.8904 - accuracy: 0.7538 - val_loss: 0.8704 - val_accuracy: 0.7800
# Epoch 13/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.8607 - accuracy: 0.7400 - val_loss: 0.8372 - val_accuracy: 0.7850
# Epoch 14/100
# 50/50 [==============================] - 9s 170ms/step - loss: 0.8072 - accuracy: 0.7675 - val_loss: 0.8036 - val_accuracy: 0.7950
# Epoch 15/100
# 50/50 [==============================] - 8s 169ms/step - loss: 0.7539 - accuracy: 0.7962 - val_loss: 0.7746 - val_accuracy: 0.7900
# Epoch 16/100
# 50/50 [==============================] - 8s 168ms/step - loss: 0.7545 - accuracy: 0.7800 - val_loss: 0.7498 - val_accuracy: 0.7900
# Epoch 17/100
# 50/50 [==============================] - 8s 165ms/step - loss: 0.7135 - accuracy: 0.7887 - val_loss: 0.7271 - val_accuracy: 0.7900
# Epoch 18/100
# 50/50 [==============================] - 8s 165ms/step - loss: 0.6889 - accuracy: 0.8087 - val_loss: 0.7082 - val_accuracy: 0.8000
# Epoch 19/100
# 50/50 [==============================] - 8s 165ms/step - loss: 0.6477 - accuracy: 0.8138 - val_loss: 0.6865 - val_accuracy: 0.8050
# Epoch 20/100
# 50/50 [==============================] - 8s 165ms/step - loss: 0.6309 - accuracy: 0.8263 - val_loss: 0.6694 - val_accuracy: 0.8150
# Epoch 21/100
# 50/50 [==============================] - 8s 165ms/step - loss: 0.6257 - accuracy: 0.8188 - val_loss: 0.6567 - val_accuracy: 0.8150
# Epoch 22/100
# 50/50 [==============================] - 8s 164ms/step - loss: 0.5820 - accuracy: 0.8400 - val_loss: 0.6417 - val_accuracy: 0.8150
# Epoch 23/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.5749 - accuracy: 0.8425 - val_loss: 0.6332 - val_accuracy: 0.8150
# Epoch 24/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.5419 - accuracy: 0.8625 - val_loss: 0.6168 - val_accuracy: 0.8150
# Epoch 25/100
# 50/50 [==============================] - 8s 165ms/step - loss: 0.5354 - accuracy: 0.8512 - val_loss: 0.6062 - val_accuracy: 0.8200
# Epoch 26/100
# 50/50 [==============================] - 9s 172ms/step - loss: 0.5222 - accuracy: 0.8662 - val_loss: 0.5978 - val_accuracy: 0.8300
# Epoch 27/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.5042 - accuracy: 0.8675 - val_loss: 0.5897 - val_accuracy: 0.8250
# Epoch 28/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.4814 - accuracy: 0.8675 - val_loss: 0.5785 - val_accuracy: 0.8150
# Epoch 29/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.4534 - accuracy: 0.8838 - val_loss: 0.5731 - val_accuracy: 0.8200
# Epoch 30/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.4531 - accuracy: 0.8737 - val_loss: 0.5653 - val_accuracy: 0.8300
# Epoch 31/100
# 50/50 [==============================] - 8s 168ms/step - loss: 0.4366 - accuracy: 0.8850 - val_loss: 0.5589 - val_accuracy: 0.8250
# Epoch 32/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.4481 - accuracy: 0.8775 - val_loss: 0.5556 - val_accuracy: 0.8200
# Epoch 33/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.4244 - accuracy: 0.8813 - val_loss: 0.5460 - val_accuracy: 0.8200
# Epoch 34/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.4160 - accuracy: 0.8725 - val_loss: 0.5391 - val_accuracy: 0.8300
# Epoch 35/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.4125 - accuracy: 0.8863 - val_loss: 0.5330 - val_accuracy: 0.8250
# Epoch 36/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.3896 - accuracy: 0.9000 - val_loss: 0.5254 - val_accuracy: 0.8250
# Epoch 37/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.3787 - accuracy: 0.9025 - val_loss: 0.5281 - val_accuracy: 0.8300
# Epoch 38/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.3947 - accuracy: 0.8950 - val_loss: 0.5214 - val_accuracy: 0.8250
# Epoch 39/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.3694 - accuracy: 0.9000 - val_loss: 0.5156 - val_accuracy: 0.8250
# Epoch 40/100
# 50/50 [==============================] - 8s 168ms/step - loss: 0.3953 - accuracy: 0.8875 - val_loss: 0.5154 - val_accuracy: 0.8300
# Epoch 41/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.3684 - accuracy: 0.8988 - val_loss: 0.5115 - val_accuracy: 0.8200
# Epoch 42/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.3555 - accuracy: 0.9162 - val_loss: 0.5106 - val_accuracy: 0.8300
# Epoch 43/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.3461 - accuracy: 0.9125 - val_loss: 0.5073 - val_accuracy: 0.8250
# Epoch 44/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.3245 - accuracy: 0.9137 - val_loss: 0.5014 - val_accuracy: 0.8250
# Epoch 45/100
# 50/50 [==============================] - 8s 168ms/step - loss: 0.3339 - accuracy: 0.9112 - val_loss: 0.5017 - val_accuracy: 0.8300
# Epoch 46/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.3378 - accuracy: 0.9125 - val_loss: 0.4985 - val_accuracy: 0.8300
# Epoch 47/100
# 50/50 [==============================] - 9s 176ms/step - loss: 0.3293 - accuracy: 0.9175 - val_loss: 0.4953 - val_accuracy: 0.8200
# Epoch 48/100
# 50/50 [==============================] - 9s 177ms/step - loss: 0.3204 - accuracy: 0.9262 - val_loss: 0.4951 - val_accuracy: 0.8250
# Epoch 49/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.3226 - accuracy: 0.9175 - val_loss: 0.4923 - val_accuracy: 0.8150
# Epoch 50/100
# 50/50 [==============================] - 9s 176ms/step - loss: 0.2990 - accuracy: 0.9162 - val_loss: 0.4905 - val_accuracy: 0.8300
# Epoch 51/100
# 50/50 [==============================] - 9s 172ms/step - loss: 0.3079 - accuracy: 0.9162 - val_loss: 0.4883 - val_accuracy: 0.8300
# Epoch 52/100
# 50/50 [==============================] - 9s 172ms/step - loss: 0.3103 - accuracy: 0.9112 - val_loss: 0.4849 - val_accuracy: 0.8300
# Epoch 53/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2811 - accuracy: 0.9300 - val_loss: 0.4808 - val_accuracy: 0.8400
# Epoch 54/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2794 - accuracy: 0.9388 - val_loss: 0.4800 - val_accuracy: 0.8250
# Epoch 55/100
# 50/50 [==============================] - 9s 170ms/step - loss: 0.2759 - accuracy: 0.9300 - val_loss: 0.4795 - val_accuracy: 0.8300
# Epoch 56/100
# 50/50 [==============================] - 8s 170ms/step - loss: 0.2680 - accuracy: 0.9438 - val_loss: 0.4759 - val_accuracy: 0.8300
# Epoch 57/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2614 - accuracy: 0.9312 - val_loss: 0.4763 - val_accuracy: 0.8350
# Epoch 58/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2637 - accuracy: 0.9362 - val_loss: 0.4711 - val_accuracy: 0.8300
# Epoch 59/100
# 50/50 [==============================] - 9s 174ms/step - loss: 0.2537 - accuracy: 0.9400 - val_loss: 0.4740 - val_accuracy: 0.8300
# Epoch 60/100
# 50/50 [==============================] - 9s 181ms/step - loss: 0.2593 - accuracy: 0.9400 - val_loss: 0.4715 - val_accuracy: 0.8350
# Epoch 61/100
# 50/50 [==============================] - 9s 173ms/step - loss: 0.2582 - accuracy: 0.9362 - val_loss: 0.4689 - val_accuracy: 0.8350
# Epoch 62/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2349 - accuracy: 0.9450 - val_loss: 0.4640 - val_accuracy: 0.8300
# Epoch 63/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2442 - accuracy: 0.9337 - val_loss: 0.4645 - val_accuracy: 0.8300
# Epoch 64/100
# 50/50 [==============================] - 8s 170ms/step - loss: 0.2378 - accuracy: 0.9463 - val_loss: 0.4612 - val_accuracy: 0.8200
# Epoch 65/100
# 50/50 [==============================] - 9s 170ms/step - loss: 0.2390 - accuracy: 0.9400 - val_loss: 0.4569 - val_accuracy: 0.8400
# Epoch 66/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2376 - accuracy: 0.9463 - val_loss: 0.4580 - val_accuracy: 0.8300
# Epoch 67/100
# 50/50 [==============================] - 9s 170ms/step - loss: 0.2313 - accuracy: 0.9475 - val_loss: 0.4572 - val_accuracy: 0.8350
# Epoch 68/100
# 50/50 [==============================] - 9s 170ms/step - loss: 0.2095 - accuracy: 0.9588 - val_loss: 0.4578 - val_accuracy: 0.8400
# Epoch 69/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2261 - accuracy: 0.9500 - val_loss: 0.4583 - val_accuracy: 0.8350
# Epoch 70/100
# 50/50 [==============================] - 9s 171ms/step - loss: 0.2118 - accuracy: 0.9488 - val_loss: 0.4583 - val_accuracy: 0.8400
# Epoch 71/100
# 50/50 [==============================] - 9s 178ms/step - loss: 0.2230 - accuracy: 0.9438 - val_loss: 0.4582 - val_accuracy: 0.8400
# Epoch 72/100
# 50/50 [==============================] - 9s 177ms/step - loss: 0.2241 - accuracy: 0.9538 - val_loss: 0.4548 - val_accuracy: 0.8350
# Epoch 73/100
# 50/50 [==============================] - 8s 168ms/step - loss: 0.1875 - accuracy: 0.9625 - val_loss: 0.4545 - val_accuracy: 0.8400
# Epoch 74/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.1899 - accuracy: 0.9650 - val_loss: 0.4536 - val_accuracy: 0.8400
# Epoch 75/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.2039 - accuracy: 0.9538 - val_loss: 0.4568 - val_accuracy: 0.8350
# Epoch 76/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.2014 - accuracy: 0.9500 - val_loss: 0.4536 - val_accuracy: 0.8350
# Epoch 77/100
# 50/50 [==============================] - 9s 174ms/step - loss: 0.1776 - accuracy: 0.9650 - val_loss: 0.4535 - val_accuracy: 0.8350
# Epoch 78/100
# 50/50 [==============================] - 9s 170ms/step - loss: 0.1847 - accuracy: 0.9613 - val_loss: 0.4542 - val_accuracy: 0.8350
# Epoch 79/100
# 50/50 [==============================] - 9s 170ms/step - loss: 0.1783 - accuracy: 0.9638 - val_loss: 0.4540 - val_accuracy: 0.8300
# Epoch 80/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.1888 - accuracy: 0.9525 - val_loss: 0.4509 - val_accuracy: 0.8400
# Epoch 81/100
# 50/50 [==============================] - 8s 169ms/step - loss: 0.1964 - accuracy: 0.9550 - val_loss: 0.4524 - val_accuracy: 0.8400
# Epoch 82/100
# 50/50 [==============================] - 8s 168ms/step - loss: 0.1995 - accuracy: 0.9538 - val_loss: 0.4511 - val_accuracy: 0.8350
# Epoch 83/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.1750 - accuracy: 0.9600 - val_loss: 0.4475 - val_accuracy: 0.8300
# Epoch 84/100
# 50/50 [==============================] - 9s 172ms/step - loss: 0.1826 - accuracy: 0.9613 - val_loss: 0.4492 - val_accuracy: 0.8300
# Epoch 85/100
# 50/50 [==============================] - 9s 178ms/step - loss: 0.1851 - accuracy: 0.9563 - val_loss: 0.4496 - val_accuracy: 0.8300
# Epoch 86/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.1687 - accuracy: 0.9675 - val_loss: 0.4472 - val_accuracy: 0.8350
# Epoch 87/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.1797 - accuracy: 0.9563 - val_loss: 0.4503 - val_accuracy: 0.8300
# Epoch 88/100
# 50/50 [==============================] - 9s 175ms/step - loss: 0.1810 - accuracy: 0.9525 - val_loss: 0.4502 - val_accuracy: 0.8250
# Epoch 89/100
# 50/50 [==============================] - 9s 173ms/step - loss: 0.1714 - accuracy: 0.9588 - val_loss: 0.4489 - val_accuracy: 0.8300
# Epoch 90/100
# 50/50 [==============================] - 9s 173ms/step - loss: 0.1500 - accuracy: 0.9712 - val_loss: 0.4486 - val_accuracy: 0.8300
# Epoch 91/100
# 50/50 [==============================] - 9s 173ms/step - loss: 0.1652 - accuracy: 0.9688 - val_loss: 0.4510 - val_accuracy: 0.8300
# Epoch 92/100
# 50/50 [==============================] - 9s 172ms/step - loss: 0.1667 - accuracy: 0.9613 - val_loss: 0.4469 - val_accuracy: 0.8300
# Epoch 93/100
# 50/50 [==============================] - 9s 173ms/step - loss: 0.1730 - accuracy: 0.9563 - val_loss: 0.4494 - val_accuracy: 0.8400
# Epoch 94/100
# 50/50 [==============================] - 9s 172ms/step - loss: 0.1752 - accuracy: 0.9650 - val_loss: 0.4517 - val_accuracy: 0.8400
# Epoch 95/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.1673 - accuracy: 0.9613 - val_loss: 0.4466 - val_accuracy: 0.8300
# Epoch 96/100
# 50/50 [==============================] - 8s 167ms/step - loss: 0.1615 - accuracy: 0.9675 - val_loss: 0.4448 - val_accuracy: 0.8300
# Epoch 97/100
# 50/50 [==============================] - 8s 165ms/step - loss: 0.1573 - accuracy: 0.9700 - val_loss: 0.4457 - val_accuracy: 0.8350
# Epoch 98/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1719 - accuracy: 0.9563 - val_loss: 0.4459 - val_accuracy: 0.8400
# Epoch 99/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1569 - accuracy: 0.9663 - val_loss: 0.4467 - val_accuracy: 0.8350
# Epoch 100/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1485 - accuracy: 0.9750 - val_loss: 0.4451 - val_accuracy: 0.8350

# %%
# cross-validated accuracy for pre-trained model before training
print("Base model accuracy:", np.mean(base_model_acc_list))
# cross-validated accuracy after training
print("Final accuracy:", np.mean(final_acc_list))
# Out:
# Base model accuracy: 0.09099999964237213
# Final accuracy: 0.8399999976158142

# %%
# plot graph of cross-validated accuracies
acc = np.mean(history_map['accuracy'], axis=0)
val_acc = np.mean(history_map['val_accuracy'], axis=0)

plt.figure(1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# plot graph of cross-validated losses
loss = np.mean(history_map['loss'], axis=0)
val_loss = np.mean(history_map['val_loss'], axis=0)

plt.figure(2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
