# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# set path to FMD image directory
data_dir = pathlib.Path("image")

# total no. of images in FMD dataset
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 1000

# %%
# set batch size for training
batch_size = 16

# set dimensions to change images into for training
# 299x299 images is required for pre-trained models like Inception V3
img_height = 299
img_width = 299

# %%
# create dataset from the image directory
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*.jpg'), shuffle=False)
# shuffle the 1,000 images with the random seed value of 123 before training
list_ds = list_ds.shuffle(image_count, seed=123, reshuffle_each_iteration=False)

# %%
# get class names from the folder names in data_dir
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['fabric' 'foliage' 'glass' 'leather' 'metal' 'paper' 'plastic' 'stone'
#  'water' 'wood']

# %%
# split dataset into 5 equal sized partitions for 5-fold cross validation
A = list_ds.shard(num_shards=5, index=0)
B = list_ds.shard(num_shards=5, index=1)
C = list_ds.shard(num_shards=5, index=2)
D = list_ds.shard(num_shards=5, index=3)
E = list_ds.shard(num_shards=5, index=4)

# %%
# check no. of samples in each partition is the same
print(A.cardinality().numpy())
print(B.cardinality().numpy())
print(C.cardinality().numpy())
print(D.cardinality().numpy())
print(E.cardinality().numpy())
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# prompt the tf.data runtime to tune the number of elements to prefetch dynamically at runtime
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# use the path of image to load the image into each partition of the dataset
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
A = A.map(process_path, num_parallel_calls=AUTOTUNE)
B = B.map(process_path, num_parallel_calls=AUTOTUNE)
C = C.map(process_path, num_parallel_calls=AUTOTUNE)
D = D.map(process_path, num_parallel_calls=AUTOTUNE)
E = E.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in A.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (299, 299, 3)
# Label:  1

# %%
# shuffle, batch, and prefetch the dataset
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
# map the dataset partitions to integers for building training/test sets during cross-validation
ds_fold_dict = {0:A, 1:B, 2:C, 3:D, 4:E}

# %%
# normalise the input values to the pre-trained model's required range of values
preprocess_input = keras.applications.inception_v3.preprocess_input

# %%
# get pre-trained model
base_model = keras.applications.InceptionV3(include_top=False, input_shape=(img_height, img_width, 3))

# %%
# don't train base model weights
base_model.trainable = False

# %%
base_model.summary()
# Out:
# 67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 17, 17, 192)  147456      mixed7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 17, 17, 192)  576         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 17, 17, 192)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 17, 17, 192)  258048      activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 17, 17, 192)  576         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 17, 17, 192)  0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 17, 17, 192)  147456      mixed7[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 17, 17, 192)  258048      activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 17, 17, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 17, 17, 192)  576         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
# set a low learning rate to avoid overfitting too quickly
base_learning_rate = 0.0001

# create the model to train using the pre-trained model as base model
def create_model():
  # generate additional training data from input training data by augmenting them using random flip, rotation & zoom
  data_augmentation = keras.Sequential(
    [
      layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                  input_shape=(img_height, 
                                                                img_width,
                                                                3)),
      layers.experimental.preprocessing.RandomRotation(0.1),
      layers.experimental.preprocessing.RandomZoom(0.1),
    ]
  )

  # average over the spatial locations to convert the features to a single vector per image
  global_average_layer = keras.layers.GlobalAveragePooling2D()
  # convert these features into a single prediction per image
  prediction_layer = keras.layers.Dense(10)

  # Build a model by chaining together the layers using the Keras Functional API.
  inputs = keras.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = preprocess_input(x)
  x = base_model(x, training=False) # use training=False as the base model contains a BatchNormalization layer
  x = global_average_layer(x)
  x = keras.layers.Dropout(0.2)(x) # add dropout to fully connected layer to reduce overfitting
  outputs = prediction_layer(x)
  model = keras.Model(inputs, outputs)
  optimizer = keras.optimizers.Adam(lr=base_learning_rate)
  loss= keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  # compile model with Adam optimizer with specified learning rate
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  model.summary()
  return model

# %%
no_epochs = 100

# %%
# store results to plot graphs and get cross-validated accuracies
history_map = {}
base_model_acc_list = []
final_acc_list = []

# do 5-fold cross-validation
for i in range(5):
  print('fold', i + 1)
  temp_dict = ds_fold_dict.copy()
  # get test set for this iteration
  current_val_ds = temp_dict[i]

  # get training set for this iteration from remaining data samples
  del temp_dict[i]
  current_train_ds = None
  for ds_shard in temp_dict.values():
    if current_train_ds is None:
      current_train_ds = ds_shard
    else:
      current_train_ds = current_train_ds.concatenate(ds_shard)
  
  # configure both training and test sets to improve performance
  current_train_ds = configure_for_performance(current_train_ds)
  current_val_ds = configure_for_performance(current_val_ds)

  # create a new model
  model = create_model()
  # get initial test accuracy
  base_model_acc_list.append(model.evaluate(current_val_ds)[1])
  # train for specified epochs
  history = model.fit(current_train_ds,
                    epochs=no_epochs,
                    validation_data=current_val_ds)
  
  # save results
  if i == 0:
    history_map['accuracy'] = [history.history['accuracy']]
    history_map['val_accuracy'] = [history.history['val_accuracy']]
    history_map['loss'] = [history.history['loss']]
    history_map['val_loss'] = [history.history['val_loss']]
  else:
    history_map['accuracy'].append(history.history['accuracy'])
    history_map['val_accuracy'].append(history.history['val_accuracy'])
    history_map['loss'].append(history.history['loss'])
    history_map['val_loss'].append(history.history['val_loss'])
  
  # get final test accuracy by taking the max accuracy over the whole training
  final_acc_list.append(np.amax(history.history['val_accuracy']))
# Out:
# val_loss: 0.5781 - val_accuracy: 0.8300
# Epoch 72/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3397 - accuracy: 0.9137 - val_loss: 0.5790 - val_accuracy: 0.8350
# Epoch 73/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.3454 - accuracy: 0.9137 - val_loss: 0.5907 - val_accuracy: 0.8400
# Epoch 74/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3547 - accuracy: 0.9112 - val_loss: 0.5888 - val_accuracy: 0.8400
# Epoch 75/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3266 - accuracy: 0.9300 - val_loss: 0.5798 - val_accuracy: 0.8400
# Epoch 76/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.3497 - accuracy: 0.9100 - val_loss: 0.5793 - val_accuracy: 0.8200
# Epoch 77/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3484 - accuracy: 0.9062 - val_loss: 0.5752 - val_accuracy: 0.8350
# Epoch 78/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3216 - accuracy: 0.9212 - val_loss: 0.5785 - val_accuracy: 0.8400
# Epoch 79/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3291 - accuracy: 0.9262 - val_loss: 0.5779 - val_accuracy: 0.8350
# Epoch 80/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3190 - accuracy: 0.9237 - val_loss: 0.5739 - val_accuracy: 0.8400
# Epoch 81/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3101 - accuracy: 0.9237 - val_loss: 0.5673 - val_accuracy: 0.8350
# Epoch 82/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3182 - accuracy: 0.9162 - val_loss: 0.5796 - val_accuracy: 0.8400
# Epoch 83/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3098 - accuracy: 0.9287 - val_loss: 0.5686 - val_accuracy: 0.8450
# Epoch 84/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3106 - accuracy: 0.9237 - val_loss: 0.5698 - val_accuracy: 0.8300
# Epoch 85/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3058 - accuracy: 0.9275 - val_loss: 0.5662 - val_accuracy: 0.8200
# Epoch 86/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2900 - accuracy: 0.9237 - val_loss: 0.5658 - val_accuracy: 0.8400
# Epoch 87/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2858 - accuracy: 0.9300 - val_loss: 0.5701 - val_accuracy: 0.8400
# Epoch 88/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2864 - accuracy: 0.9362 - val_loss: 0.5649 - val_accuracy: 0.8250
# Epoch 89/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2772 - accuracy: 0.9350 - val_loss: 0.5699 - val_accuracy: 0.8350
# Epoch 90/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2835 - accuracy: 0.9450 - val_loss: 0.5627 - val_accuracy: 0.8300
# Epoch 91/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2813 - accuracy: 0.9287 - val_loss: 0.5611 - val_accuracy: 0.8250
# Epoch 92/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2781 - accuracy: 0.9375 - val_loss: 0.5716 - val_accuracy: 0.8300
# Epoch 93/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2624 - accuracy: 0.9463 - val_loss: 0.5684 - val_accuracy: 0.8350
# Epoch 94/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2759 - accuracy: 0.9450 - val_loss: 0.5567 - val_accuracy: 0.8500
# Epoch 95/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2833 - accuracy: 0.9337 - val_loss: 0.5637 - val_accuracy: 0.8550
# Epoch 96/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2657 - accuracy: 0.9325 - val_loss: 0.5627 - val_accuracy: 0.8200
# Epoch 97/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2734 - accuracy: 0.9375 - val_loss: 0.5563 - val_accuracy: 0.8350
# Epoch 98/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2595 - accuracy: 0.9438 - val_loss: 0.5620 - val_accuracy: 0.8250
# Epoch 99/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2707 - accuracy: 0.9362 - val_loss: 0.5575 - val_accuracy: 0.8200
# Epoch 100/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.2493 - accuracy: 0.9375 - val_loss: 0.5683 - val_accuracy: 0.8350
# fold 5
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 21,823,274
# Trainable params: 20,490
# Non-trainable params: 21,802,784
# _________________________________________________________________
# 13/13 [==============================] - 0s 36ms/step - loss: 2.4185 - accuracy: 0.1200
# Epoch 1/100
# 50/50 [==============================] - 3s 51ms/step - loss: 2.4499 - accuracy: 0.1175 - val_loss: 2.1923 - val_accuracy: 0.1950
# Epoch 2/100
# 50/50 [==============================] - 3s 51ms/step - loss: 2.2103 - accuracy: 0.1975 - val_loss: 2.0132 - val_accuracy: 0.3600
# Epoch 3/100
# 50/50 [==============================] - 3s 51ms/step - loss: 2.0358 - accuracy: 0.3050 - val_loss: 1.8779 - val_accuracy: 0.4200
# Epoch 4/100
# 50/50 [==============================] - 3s 51ms/step - loss: 1.8982 - accuracy: 0.3537 - val_loss: 1.7573 - val_accuracy: 0.5150
# Epoch 5/100
# 50/50 [==============================] - 3s 51ms/step - loss: 1.7404 - accuracy: 0.4525 - val_loss: 1.6454 - val_accuracy: 0.5650
# Epoch 6/100
# 50/50 [==============================] - 3s 51ms/step - loss: 1.6302 - accuracy: 0.5088 - val_loss: 1.5516 - val_accuracy: 0.6000
# Epoch 7/100
# 50/50 [==============================] - 3s 51ms/step - loss: 1.5152 - accuracy: 0.5625 - val_loss: 1.4649 - val_accuracy: 0.6650
# Epoch 8/100
# 50/50 [==============================] - 3s 51ms/step - loss: 1.4200 - accuracy: 0.5738 - val_loss: 1.3868 - val_accuracy: 0.7100
# Epoch 9/100
# 50/50 [==============================] - 3s 51ms/step - loss: 1.3172 - accuracy: 0.6637 - val_loss: 1.3197 - val_accuracy: 0.7450
# Epoch 10/100
# 50/50 [==============================] - 3s 52ms/step - loss: 1.2570 - accuracy: 0.6837 - val_loss: 1.2618 - val_accuracy: 0.7500
# Epoch 11/100
# 50/50 [==============================] - 3s 51ms/step - loss: 1.1908 - accuracy: 0.6700 - val_loss: 1.2070 - val_accuracy: 0.7700
# Epoch 12/100
# 50/50 [==============================] - 3s 52ms/step - loss: 1.1368 - accuracy: 0.7063 - val_loss: 1.1712 - val_accuracy: 0.7750
# Epoch 13/100
# 50/50 [==============================] - 3s 52ms/step - loss: 1.0786 - accuracy: 0.7475 - val_loss: 1.1238 - val_accuracy: 0.7850
# Epoch 14/100
# 50/50 [==============================] - 3s 51ms/step - loss: 1.0353 - accuracy: 0.7588 - val_loss: 1.0883 - val_accuracy: 0.7900
# Epoch 15/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.9924 - accuracy: 0.7538 - val_loss: 1.0503 - val_accuracy: 0.7750
# Epoch 16/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.9660 - accuracy: 0.7613 - val_loss: 1.0256 - val_accuracy: 0.7850
# Epoch 17/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.9219 - accuracy: 0.7763 - val_loss: 0.9999 - val_accuracy: 0.8000
# Epoch 18/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.8920 - accuracy: 0.7900 - val_loss: 0.9744 - val_accuracy: 0.7950
# Epoch 19/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.8798 - accuracy: 0.7738 - val_loss: 0.9542 - val_accuracy: 0.7900
# Epoch 20/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.8285 - accuracy: 0.7900 - val_loss: 0.9212 - val_accuracy: 0.7950
# Epoch 21/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.7942 - accuracy: 0.8025 - val_loss: 0.9110 - val_accuracy: 0.8050
# Epoch 22/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.7747 - accuracy: 0.8112 - val_loss: 0.8857 - val_accuracy: 0.8050
# Epoch 23/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.7556 - accuracy: 0.8325 - val_loss: 0.8708 - val_accuracy: 0.8050
# Epoch 24/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.7342 - accuracy: 0.8188 - val_loss: 0.8590 - val_accuracy: 0.8000
# Epoch 25/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.7262 - accuracy: 0.8163 - val_loss: 0.8407 - val_accuracy: 0.8000
# Epoch 26/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.6795 - accuracy: 0.8413 - val_loss: 0.8293 - val_accuracy: 0.8000
# Epoch 27/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.6797 - accuracy: 0.8438 - val_loss: 0.8204 - val_accuracy: 0.8100
# Epoch 28/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.6574 - accuracy: 0.8363 - val_loss: 0.8052 - val_accuracy: 0.8050
# Epoch 29/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.6547 - accuracy: 0.8350 - val_loss: 0.7922 - val_accuracy: 0.8200
# Epoch 30/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.6431 - accuracy: 0.8388 - val_loss: 0.7816 - val_accuracy: 0.8050
# Epoch 31/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.6311 - accuracy: 0.8475 - val_loss: 0.7730 - val_accuracy: 0.8000
# Epoch 32/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.6280 - accuracy: 0.8413 - val_loss: 0.7618 - val_accuracy: 0.8050
# Epoch 33/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5911 - accuracy: 0.8462 - val_loss: 0.7616 - val_accuracy: 0.8050
# Epoch 34/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.5854 - accuracy: 0.8600 - val_loss: 0.7464 - val_accuracy: 0.8200
# Epoch 35/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5712 - accuracy: 0.8662 - val_loss: 0.7452 - val_accuracy: 0.8000
# Epoch 36/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5565 - accuracy: 0.8725 - val_loss: 0.7320 - val_accuracy: 0.8100
# Epoch 37/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5389 - accuracy: 0.8712 - val_loss: 0.7203 - val_accuracy: 0.8300
# Epoch 38/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5215 - accuracy: 0.8763 - val_loss: 0.7240 - val_accuracy: 0.8100
# Epoch 39/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5517 - accuracy: 0.8650 - val_loss: 0.7094 - val_accuracy: 0.8150
# Epoch 40/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5053 - accuracy: 0.8813 - val_loss: 0.7157 - val_accuracy: 0.8100
# Epoch 41/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.5295 - accuracy: 0.8625 - val_loss: 0.6994 - val_accuracy: 0.8100
# Epoch 42/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.5218 - accuracy: 0.8650 - val_loss: 0.6992 - val_accuracy: 0.8100
# Epoch 43/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.4999 - accuracy: 0.8875 - val_loss: 0.6920 - val_accuracy: 0.8100
# Epoch 44/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.5173 - accuracy: 0.8725 - val_loss: 0.6879 - val_accuracy: 0.8150
# Epoch 45/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.4882 - accuracy: 0.8800 - val_loss: 0.6765 - val_accuracy: 0.8050
# Epoch 46/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.4735 - accuracy: 0.8875 - val_loss: 0.6810 - val_accuracy: 0.8100
# Epoch 47/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.4636 - accuracy: 0.8888 - val_loss: 0.6760 - val_accuracy: 0.8150
# Epoch 48/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.4853 - accuracy: 0.8775 - val_loss: 0.6681 - val_accuracy: 0.8250
# Epoch 49/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.4480 - accuracy: 0.9013 - val_loss: 0.6662 - val_accuracy: 0.8150
# Epoch 50/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.4341 - accuracy: 0.9000 - val_loss: 0.6565 - val_accuracy: 0.8300
# Epoch 51/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.4566 - accuracy: 0.8800 - val_loss: 0.6586 - val_accuracy: 0.8150
# Epoch 52/100
# 50/50 [==============================] - 3s 55ms/step - loss: 0.4454 - accuracy: 0.8863 - val_loss: 0.6655 - val_accuracy: 0.8100
# Epoch 53/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.4449 - accuracy: 0.8875 - val_loss: 0.6559 - val_accuracy: 0.8100
# Epoch 54/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.4332 - accuracy: 0.8875 - val_loss: 0.6423 - val_accuracy: 0.8250
# Epoch 55/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3982 - accuracy: 0.8975 - val_loss: 0.6488 - val_accuracy: 0.8200
# Epoch 56/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.4136 - accuracy: 0.8925 - val_loss: 0.6445 - val_accuracy: 0.8150
# Epoch 57/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.4061 - accuracy: 0.8988 - val_loss: 0.6391 - val_accuracy: 0.8150
# Epoch 58/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3893 - accuracy: 0.9100 - val_loss: 0.6417 - val_accuracy: 0.8200
# Epoch 59/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3928 - accuracy: 0.9100 - val_loss: 0.6269 - val_accuracy: 0.8250
# Epoch 60/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3868 - accuracy: 0.9038 - val_loss: 0.6263 - val_accuracy: 0.8300
# Epoch 61/100
# 50/50 [==============================] - 3s 51ms/step - loss: 0.3778 - accuracy: 0.9062 - val_loss: 0.6415 - val_accuracy: 0.8100
# Epoch 62/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3970 - accuracy: 0.9025 - val_loss: 0.6298 - val_accuracy: 0.8200
# Epoch 63/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3799 - accuracy: 0.9112 - val_loss: 0.6251 - val_accuracy: 0.8250
# Epoch 64/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3815 - accuracy: 0.9062 - val_loss: 0.6258 - val_accuracy: 0.8250
# Epoch 65/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.3653 - accuracy: 0.9062 - val_loss: 0.6252 - val_accuracy: 0.8150
# Epoch 66/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3594 - accuracy: 0.9162 - val_loss: 0.6244 - val_accuracy: 0.8150
# Epoch 67/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.3657 - accuracy: 0.9125 - val_loss: 0.6209 - val_accuracy: 0.8300
# Epoch 68/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3467 - accuracy: 0.9200 - val_loss: 0.6288 - val_accuracy: 0.8150
# Epoch 69/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.3503 - accuracy: 0.9162 - val_loss: 0.6173 - val_accuracy: 0.8250
# Epoch 70/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3366 - accuracy: 0.9237 - val_loss: 0.6085 - val_accuracy: 0.8300
# Epoch 71/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.3495 - accuracy: 0.9075 - val_loss: 0.6109 - val_accuracy: 0.8250
# Epoch 72/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3506 - accuracy: 0.9062 - val_loss: 0.6142 - val_accuracy: 0.8200
# Epoch 73/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3566 - accuracy: 0.9038 - val_loss: 0.6142 - val_accuracy: 0.8300
# Epoch 74/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3331 - accuracy: 0.9212 - val_loss: 0.6116 - val_accuracy: 0.8250
# Epoch 75/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3265 - accuracy: 0.9250 - val_loss: 0.6228 - val_accuracy: 0.8150
# Epoch 76/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3148 - accuracy: 0.9187 - val_loss: 0.6118 - val_accuracy: 0.8350
# Epoch 77/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3193 - accuracy: 0.9225 - val_loss: 0.6017 - val_accuracy: 0.8300
# Epoch 78/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3163 - accuracy: 0.9237 - val_loss: 0.6106 - val_accuracy: 0.8300
# Epoch 79/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3190 - accuracy: 0.9237 - val_loss: 0.6084 - val_accuracy: 0.8300
# Epoch 80/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3143 - accuracy: 0.9325 - val_loss: 0.6086 - val_accuracy: 0.8300
# Epoch 81/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3093 - accuracy: 0.9237 - val_loss: 0.6068 - val_accuracy: 0.8250
# Epoch 82/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3142 - accuracy: 0.9262 - val_loss: 0.6002 - val_accuracy: 0.8250
# Epoch 83/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.3100 - accuracy: 0.9225 - val_loss: 0.5970 - val_accuracy: 0.8250
# Epoch 84/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2984 - accuracy: 0.9300 - val_loss: 0.6050 - val_accuracy: 0.8300
# Epoch 85/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.3174 - accuracy: 0.9275 - val_loss: 0.5983 - val_accuracy: 0.8200
# Epoch 86/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2715 - accuracy: 0.9375 - val_loss: 0.5939 - val_accuracy: 0.8250
# Epoch 87/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2814 - accuracy: 0.9388 - val_loss: 0.5955 - val_accuracy: 0.8250
# Epoch 88/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.2854 - accuracy: 0.9300 - val_loss: 0.5955 - val_accuracy: 0.8250
# Epoch 89/100
# 50/50 [==============================] - 3s 54ms/step - loss: 0.2843 - accuracy: 0.9337 - val_loss: 0.5873 - val_accuracy: 0.8250
# Epoch 90/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2803 - accuracy: 0.9362 - val_loss: 0.5917 - val_accuracy: 0.8300
# Epoch 91/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2599 - accuracy: 0.9413 - val_loss: 0.6021 - val_accuracy: 0.8200
# Epoch 92/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2720 - accuracy: 0.9350 - val_loss: 0.5956 - val_accuracy: 0.8200
# Epoch 93/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2807 - accuracy: 0.9438 - val_loss: 0.6013 - val_accuracy: 0.8100
# Epoch 94/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2812 - accuracy: 0.9350 - val_loss: 0.5936 - val_accuracy: 0.8200
# Epoch 95/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2851 - accuracy: 0.9325 - val_loss: 0.5860 - val_accuracy: 0.8200
# Epoch 96/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2662 - accuracy: 0.9463 - val_loss: 0.5852 - val_accuracy: 0.8300
# Epoch 97/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2579 - accuracy: 0.9463 - val_loss: 0.5871 - val_accuracy: 0.8250
# Epoch 98/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2712 - accuracy: 0.9275 - val_loss: 0.5851 - val_accuracy: 0.8200
# Epoch 99/100
# 50/50 [==============================] - 3s 52ms/step - loss: 0.2651 - accuracy: 0.9362 - val_loss: 0.5817 - val_accuracy: 0.8300
# Epoch 100/100
# 50/50 [==============================] - 3s 53ms/step - loss: 0.2660 - accuracy: 0.9425 - val_loss: 0.5858 - val_accuracy: 0.8150

# %%
# cross-validated accuracy for pre-trained model before training
print("Base model accuracy:", np.mean(base_model_acc_list))
# cross-validated accuracy after training
print("Final accuracy:", np.mean(final_acc_list))
# Out:
# Base model accuracy: 0.09099999889731407
# Final accuracy: 0.8339999914169312

# %%
# plot graph of cross-validated accuracies
acc = np.mean(history_map['accuracy'], axis=0)
val_acc = np.mean(history_map['val_accuracy'], axis=0)

plt.figure(1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# plot graph of cross-validated losses
loss = np.mean(history_map['loss'], axis=0)
val_loss = np.mean(history_map['val_loss'], axis=0)

plt.figure(2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
