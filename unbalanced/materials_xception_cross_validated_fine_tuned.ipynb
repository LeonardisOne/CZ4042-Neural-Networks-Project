# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# set path to FMD image directory
data_dir = pathlib.Path("image")

# total no. of images in FMD dataset
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 1000

# %%
# set batch size for training
batch_size = 16

# set dimensions to change images into for training
# 299x299 images is used to train for consistency between different pre-trained models
img_height = 299
img_width = 299

# %%
# create dataset from the image directory
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*.jpg'), shuffle=False)
# shuffle the 1,000 images with the random seed value of 123 before training
list_ds = list_ds.shuffle(image_count, seed=123, reshuffle_each_iteration=False)

# %%
# get class names from the folder names in data_dir
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['fabric' 'foliage' 'glass' 'leather' 'metal' 'paper' 'plastic' 'stone'
#  'water' 'wood']

# %%
# split dataset into 5 equal sized parts for 5-fold cross validation
A = list_ds.shard(num_shards=5, index=0)
B = list_ds.shard(num_shards=5, index=1)
C = list_ds.shard(num_shards=5, index=2)
D = list_ds.shard(num_shards=5, index=3)
E = list_ds.shard(num_shards=5, index=4)

# %%
# check no. of samples in each partition is the same
print(A.cardinality().numpy())
print(B.cardinality().numpy())
print(C.cardinality().numpy())
print(D.cardinality().numpy())
print(E.cardinality().numpy())
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# prompt the tf.data runtime to tune the number of elements to prefetch dynamically at runtime
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# use the path of image to load the image into each partition of the dataset
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
A = A.map(process_path, num_parallel_calls=AUTOTUNE)
B = B.map(process_path, num_parallel_calls=AUTOTUNE)
C = C.map(process_path, num_parallel_calls=AUTOTUNE)
D = D.map(process_path, num_parallel_calls=AUTOTUNE)
E = E.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in A.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (299, 299, 3)
# Label:  1

# %%
# shuffle, batch, and prefetch the dataset
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
# map the dataset partitions to integers for building training/test sets during cross-validation
ds_fold_dict = {0:A, 1:B, 2:C, 3:D, 4:E}

# %%
# normalise the input values to the pre-trained model's required range of values
preprocess_input = keras.applications.xception.preprocess_input

# %%
# set a low learning rate to avoid overfitting too quickly
base_learning_rate = 0.0001

# create the model to train using the pre-trained model as base model
def create_model(base_model):
  # generate additional training data from input training data by augmenting them using random flip, rotation & zoom
  data_augmentation = keras.Sequential(
    [
      layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                  input_shape=(img_height, 
                                                                img_width,
                                                                3)),
      layers.experimental.preprocessing.RandomRotation(0.1),
      layers.experimental.preprocessing.RandomZoom(0.1),
    ]
  )

  # average over the spatial locations to convert the features to a single vector per image
  global_average_layer = keras.layers.GlobalAveragePooling2D()
  # convert these features into a single prediction per image
  prediction_layer = keras.layers.Dense(10)

  # Build a model by chaining together the layers using the Keras Functional API.
  inputs = keras.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = preprocess_input(x)
  x = base_model(x, training=False) # use training=False as the base model contains a BatchNormalization layer
  x = global_average_layer(x)
  x = keras.layers.Dropout(0.2)(x) # add dropout to fully connected layer to reduce overfitting
  outputs = prediction_layer(x)
  model = keras.Model(inputs, outputs)
  optimizer = keras.optimizers.Adam(lr=base_learning_rate)
  loss= keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  # compile model with Adam optimizer with specified learning rate
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  model.summary()
  return model

# %%
no_epochs = 50
fine_tune_epochs = 20
total_epochs =  no_epochs + fine_tune_epochs
# Fine-tune from this layer onwards
fine_tune_at = 115

# %%
# store results to plot graphs and get cross-validated accuracies
history_map = {}
base_model_acc_list = []
pre_trained_acc_list = []
final_acc_list = []

# do 5-fold cross-validation
for i in range(5):
  print('fold', i + 1)
  temp_dict = ds_fold_dict.copy()
  # get test set for this iteration
  current_val_ds = temp_dict[i]

  # get training set for this iteration from remaining data samples
  del temp_dict[i]
  current_train_ds = None
  for ds_shard in temp_dict.values():
    if current_train_ds is None:
      current_train_ds = ds_shard
    else:
      current_train_ds = current_train_ds.concatenate(ds_shard)
  
  # configure both training and test sets to improve performance
  current_train_ds = configure_for_performance(current_train_ds)
  current_val_ds = configure_for_performance(current_val_ds)

  # get pre-trained model
  base_model = keras.applications.Xception(include_top=False, input_shape=(img_height, img_width, 3))
  # don't train base model weights
  base_model.trainable = False

  # create a new model
  model = create_model(base_model)
  # get initial test accuracy
  base_model_acc_list.append(model.evaluate(current_val_ds)[1])
  # train for specified epochs
  history = model.fit(current_train_ds,
                    epochs=no_epochs,
                    validation_data=current_val_ds)
  
  # get test accuracy before fine-tuning
  pre_trained_acc_list.append(model.evaluate(current_val_ds)[1])

  # start fine-tuning by setting base model to be trainable
  base_model.trainable = True

  # Freeze all the layers before the `fine_tune_at` layer to only fine-tune top layer(s)
  for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False

  # compile model again with RMSProp optimizer with even smaller learning rate to reduce overfitting
  optimizer = keras.optimizers.RMSprop(lr=base_learning_rate/10)
  loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  print('Fine-tuned model:')
  model.summary()

  # train fine-tuned model
  history_fine = model.fit(current_train_ds,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=current_val_ds)

  # save results
  if i == 0:
    history_map['accuracy'] = [history.history['accuracy'] + history_fine.history['accuracy']]
    history_map['val_accuracy'] = [history.history['val_accuracy'] + history_fine.history['val_accuracy']]
    history_map['loss'] = [history.history['loss'] + history_fine.history['loss']]
    history_map['val_loss'] = [history.history['val_loss'] + history_fine.history['val_loss']]
  else:
    history_map['accuracy'].append(history.history['accuracy'] + history_fine.history['accuracy'])
    history_map['val_accuracy'].append(history.history['val_accuracy'] + history_fine.history['val_accuracy'])
    history_map['loss'].append(history.history['loss'] + history_fine.history['loss'])
    history_map['val_loss'].append(history.history['val_loss'] + history_fine.history['val_loss'])
  
  # get final test accuracy by taking the max accuracy over the whole training due to potential overfitting at end of fine-tuning
  final_acc_list.append(np.amax(history.history['val_accuracy'] + history_fine.history['val_accuracy']))
# Out:
#  - val_loss: 0.7460 - val_accuracy: 0.8250
# Epoch 35/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6293 - accuracy: 0.8800 - val_loss: 0.7347 - val_accuracy: 0.8250
# Epoch 36/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6154 - accuracy: 0.8763 - val_loss: 0.7287 - val_accuracy: 0.8250
# Epoch 37/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6022 - accuracy: 0.8838 - val_loss: 0.7157 - val_accuracy: 0.8300
# Epoch 38/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5869 - accuracy: 0.8850 - val_loss: 0.7111 - val_accuracy: 0.8300
# Epoch 39/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5773 - accuracy: 0.8863 - val_loss: 0.7014 - val_accuracy: 0.8300
# Epoch 40/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5779 - accuracy: 0.8725 - val_loss: 0.6918 - val_accuracy: 0.8350
# Epoch 41/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5625 - accuracy: 0.8800 - val_loss: 0.6809 - val_accuracy: 0.8400
# Epoch 42/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5427 - accuracy: 0.8913 - val_loss: 0.6747 - val_accuracy: 0.8400
# Epoch 43/50
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5456 - accuracy: 0.8875 - val_loss: 0.6718 - val_accuracy: 0.8400
# Epoch 44/50
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5506 - accuracy: 0.8763 - val_loss: 0.6666 - val_accuracy: 0.8350
# Epoch 45/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5438 - accuracy: 0.8788 - val_loss: 0.6607 - val_accuracy: 0.8350
# Epoch 46/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5104 - accuracy: 0.8963 - val_loss: 0.6516 - val_accuracy: 0.8400
# Epoch 47/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5140 - accuracy: 0.8800 - val_loss: 0.6512 - val_accuracy: 0.8400
# Epoch 48/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.4964 - accuracy: 0.9013 - val_loss: 0.6442 - val_accuracy: 0.8350
# Epoch 49/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.4988 - accuracy: 0.8788 - val_loss: 0.6405 - val_accuracy: 0.8350
# Epoch 50/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.4809 - accuracy: 0.8988 - val_loss: 0.6302 - val_accuracy: 0.8450
# 13/13 [==============================] - 1s 59ms/step - loss: 0.6302 - accuracy: 0.8450
# Fine-tuned model:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_3 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 20,881,970
# Trainable params: 6,808,874
# Non-trainable params: 14,073,096
# _________________________________________________________________
# Epoch 50/70
# 50/50 [==============================] - 6s 119ms/step - loss: 0.3912 - accuracy: 0.8925 - val_loss: 0.5242 - val_accuracy: 0.8350
# Epoch 51/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2894 - accuracy: 0.9150 - val_loss: 0.5347 - val_accuracy: 0.8400
# Epoch 52/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2757 - accuracy: 0.8988 - val_loss: 0.5036 - val_accuracy: 0.8400
# Epoch 53/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2332 - accuracy: 0.9237 - val_loss: 0.5139 - val_accuracy: 0.8350
# Epoch 54/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2202 - accuracy: 0.9175 - val_loss: 0.5199 - val_accuracy: 0.8450
# Epoch 55/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.2039 - accuracy: 0.9287 - val_loss: 0.5019 - val_accuracy: 0.8450
# Epoch 56/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2093 - accuracy: 0.9300 - val_loss: 0.5119 - val_accuracy: 0.8400
# Epoch 57/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1727 - accuracy: 0.9325 - val_loss: 0.5156 - val_accuracy: 0.8500
# Epoch 58/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.1639 - accuracy: 0.9388 - val_loss: 0.5436 - val_accuracy: 0.8300
# Epoch 59/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.1436 - accuracy: 0.9563 - val_loss: 0.5501 - val_accuracy: 0.8450
# Epoch 60/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1307 - accuracy: 0.9538 - val_loss: 0.5311 - val_accuracy: 0.8550
# Epoch 61/70
# 50/50 [==============================] - 5s 107ms/step - loss: 0.1263 - accuracy: 0.9638 - val_loss: 0.5300 - val_accuracy: 0.8450
# Epoch 62/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.1298 - accuracy: 0.9575 - val_loss: 0.5347 - val_accuracy: 0.8450
# Epoch 63/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.1117 - accuracy: 0.9663 - val_loss: 0.5076 - val_accuracy: 0.8600
# Epoch 64/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1136 - accuracy: 0.9600 - val_loss: 0.5356 - val_accuracy: 0.8350
# Epoch 65/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0868 - accuracy: 0.9750 - val_loss: 0.5683 - val_accuracy: 0.8400
# Epoch 66/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0808 - accuracy: 0.9688 - val_loss: 0.5525 - val_accuracy: 0.8450
# Epoch 67/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0878 - accuracy: 0.9737 - val_loss: 0.6453 - val_accuracy: 0.8300
# Epoch 68/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0839 - accuracy: 0.9712 - val_loss: 0.5578 - val_accuracy: 0.8550
# Epoch 69/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0743 - accuracy: 0.9775 - val_loss: 0.5886 - val_accuracy: 0.8300
# Epoch 70/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0621 - accuracy: 0.9787 - val_loss: 0.5733 - val_accuracy: 0.8550
# fold 5
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 20,881,970
# Trainable params: 20,490
# Non-trainable params: 20,861,480
# _________________________________________________________________
# 13/13 [==============================] - 1s 61ms/step - loss: 2.3221 - accuracy: 0.0850
# Epoch 1/50
# 50/50 [==============================] - 4s 85ms/step - loss: 2.3058 - accuracy: 0.1312 - val_loss: 2.1926 - val_accuracy: 0.2450
# Epoch 2/50
# 50/50 [==============================] - 4s 85ms/step - loss: 2.1474 - accuracy: 0.2338 - val_loss: 2.0717 - val_accuracy: 0.3100
# Epoch 3/50
# 50/50 [==============================] - 4s 87ms/step - loss: 2.0163 - accuracy: 0.3850 - val_loss: 1.9561 - val_accuracy: 0.4300
# Epoch 4/50
# 50/50 [==============================] - 4s 87ms/step - loss: 1.8977 - accuracy: 0.4750 - val_loss: 1.8527 - val_accuracy: 0.5250
# Epoch 5/50
# 50/50 [==============================] - 4s 87ms/step - loss: 1.7924 - accuracy: 0.5663 - val_loss: 1.7548 - val_accuracy: 0.5900
# Epoch 6/50
# 50/50 [==============================] - 4s 87ms/step - loss: 1.6910 - accuracy: 0.6350 - val_loss: 1.6655 - val_accuracy: 0.6350
# Epoch 7/50
# 50/50 [==============================] - 4s 87ms/step - loss: 1.5996 - accuracy: 0.6687 - val_loss: 1.5835 - val_accuracy: 0.6600
# Epoch 8/50
# 50/50 [==============================] - 4s 88ms/step - loss: 1.4935 - accuracy: 0.7375 - val_loss: 1.5088 - val_accuracy: 0.7000
# Epoch 9/50
# 50/50 [==============================] - 4s 87ms/step - loss: 1.4208 - accuracy: 0.7450 - val_loss: 1.4437 - val_accuracy: 0.7150
# Epoch 10/50
# 50/50 [==============================] - 4s 86ms/step - loss: 1.3578 - accuracy: 0.7675 - val_loss: 1.3771 - val_accuracy: 0.7300
# Epoch 11/50
# 50/50 [==============================] - 4s 86ms/step - loss: 1.2793 - accuracy: 0.7862 - val_loss: 1.3218 - val_accuracy: 0.7450
# Epoch 12/50
# 50/50 [==============================] - 4s 86ms/step - loss: 1.2210 - accuracy: 0.7975 - val_loss: 1.2740 - val_accuracy: 0.7450
# Epoch 13/50
# 50/50 [==============================] - 4s 86ms/step - loss: 1.1615 - accuracy: 0.8150 - val_loss: 1.2232 - val_accuracy: 0.7450
# Epoch 14/50
# 50/50 [==============================] - 4s 86ms/step - loss: 1.1217 - accuracy: 0.8350 - val_loss: 1.1828 - val_accuracy: 0.7450
# Epoch 15/50
# 50/50 [==============================] - 4s 86ms/step - loss: 1.0764 - accuracy: 0.8062 - val_loss: 1.1448 - val_accuracy: 0.7450
# Epoch 16/50
# 50/50 [==============================] - 4s 86ms/step - loss: 1.0353 - accuracy: 0.8313 - val_loss: 1.1066 - val_accuracy: 0.7550
# Epoch 17/50
# 50/50 [==============================] - 4s 86ms/step - loss: 0.9894 - accuracy: 0.8338 - val_loss: 1.0718 - val_accuracy: 0.7550
# Epoch 18/50
# 50/50 [==============================] - 4s 86ms/step - loss: 0.9707 - accuracy: 0.8300 - val_loss: 1.0415 - val_accuracy: 0.7600
# Epoch 19/50
# 50/50 [==============================] - 4s 89ms/step - loss: 0.9166 - accuracy: 0.8537 - val_loss: 1.0132 - val_accuracy: 0.7700
# Epoch 20/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.8947 - accuracy: 0.8487 - val_loss: 0.9901 - val_accuracy: 0.7700
# Epoch 21/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.8946 - accuracy: 0.8300 - val_loss: 0.9666 - val_accuracy: 0.7750
# Epoch 22/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.8355 - accuracy: 0.8487 - val_loss: 0.9445 - val_accuracy: 0.7850
# Epoch 23/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.8186 - accuracy: 0.8600 - val_loss: 0.9216 - val_accuracy: 0.7900
# Epoch 24/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.8097 - accuracy: 0.8425 - val_loss: 0.9012 - val_accuracy: 0.7900
# Epoch 25/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.7902 - accuracy: 0.8462 - val_loss: 0.8848 - val_accuracy: 0.7900
# Epoch 26/50
# 50/50 [==============================] - 4s 89ms/step - loss: 0.7512 - accuracy: 0.8575 - val_loss: 0.8698 - val_accuracy: 0.7950
# Epoch 27/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.7280 - accuracy: 0.8750 - val_loss: 0.8504 - val_accuracy: 0.8050
# Epoch 28/50
# 50/50 [==============================] - 4s 89ms/step - loss: 0.7235 - accuracy: 0.8675 - val_loss: 0.8351 - val_accuracy: 0.8050
# Epoch 29/50
# 50/50 [==============================] - 4s 89ms/step - loss: 0.6923 - accuracy: 0.8800 - val_loss: 0.8229 - val_accuracy: 0.8200
# Epoch 30/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6790 - accuracy: 0.8737 - val_loss: 0.8085 - val_accuracy: 0.8200
# Epoch 31/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6718 - accuracy: 0.8788 - val_loss: 0.7939 - val_accuracy: 0.8150
# Epoch 32/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6511 - accuracy: 0.8800 - val_loss: 0.7801 - val_accuracy: 0.8200
# Epoch 33/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6478 - accuracy: 0.8587 - val_loss: 0.7715 - val_accuracy: 0.8250
# Epoch 34/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6333 - accuracy: 0.8813 - val_loss: 0.7601 - val_accuracy: 0.8350
# Epoch 35/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6047 - accuracy: 0.8988 - val_loss: 0.7471 - val_accuracy: 0.8350
# Epoch 36/50
# 50/50 [==============================] - 4s 89ms/step - loss: 0.5945 - accuracy: 0.8900 - val_loss: 0.7426 - val_accuracy: 0.8200
# Epoch 37/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.6005 - accuracy: 0.8850 - val_loss: 0.7307 - val_accuracy: 0.8250
# Epoch 38/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5885 - accuracy: 0.8850 - val_loss: 0.7219 - val_accuracy: 0.8300
# Epoch 39/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5664 - accuracy: 0.8950 - val_loss: 0.7139 - val_accuracy: 0.8300
# Epoch 40/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5793 - accuracy: 0.8662 - val_loss: 0.7066 - val_accuracy: 0.8250
# Epoch 41/50
# 50/50 [==============================] - 4s 86ms/step - loss: 0.5550 - accuracy: 0.8888 - val_loss: 0.6971 - val_accuracy: 0.8300
# Epoch 42/50
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5405 - accuracy: 0.8913 - val_loss: 0.6886 - val_accuracy: 0.8300
# Epoch 43/50
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5440 - accuracy: 0.8950 - val_loss: 0.6823 - val_accuracy: 0.8400
# Epoch 44/50
# 50/50 [==============================] - 4s 86ms/step - loss: 0.5315 - accuracy: 0.8888 - val_loss: 0.6745 - val_accuracy: 0.8350
# Epoch 45/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5294 - accuracy: 0.8888 - val_loss: 0.6717 - val_accuracy: 0.8300
# Epoch 46/50
# 50/50 [==============================] - 4s 89ms/step - loss: 0.5225 - accuracy: 0.8950 - val_loss: 0.6662 - val_accuracy: 0.8350
# Epoch 47/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5060 - accuracy: 0.8988 - val_loss: 0.6566 - val_accuracy: 0.8400
# Epoch 48/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.4854 - accuracy: 0.8988 - val_loss: 0.6488 - val_accuracy: 0.8350
# Epoch 49/50
# 50/50 [==============================] - 4s 88ms/step - loss: 0.5002 - accuracy: 0.8850 - val_loss: 0.6452 - val_accuracy: 0.8400
# Epoch 50/50
# 50/50 [==============================] - 4s 89ms/step - loss: 0.4717 - accuracy: 0.9100 - val_loss: 0.6370 - val_accuracy: 0.8400
# 13/13 [==============================] - 1s 62ms/step - loss: 0.6370 - accuracy: 0.8400
# Fine-tuned model:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 20,881,970
# Trainable params: 6,808,874
# Non-trainable params: 14,073,096
# _________________________________________________________________
# Epoch 50/70
# 50/50 [==============================] - 6s 120ms/step - loss: 0.3679 - accuracy: 0.9038 - val_loss: 0.5084 - val_accuracy: 0.8500
# Epoch 51/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.3128 - accuracy: 0.8963 - val_loss: 0.4722 - val_accuracy: 0.8550
# Epoch 52/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2698 - accuracy: 0.9125 - val_loss: 0.4594 - val_accuracy: 0.8600
# Epoch 53/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2453 - accuracy: 0.9162 - val_loss: 0.4634 - val_accuracy: 0.8650
# Epoch 54/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2375 - accuracy: 0.9275 - val_loss: 0.4363 - val_accuracy: 0.8600
# Epoch 55/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1987 - accuracy: 0.9375 - val_loss: 0.4379 - val_accuracy: 0.8500
# Epoch 56/70
# 50/50 [==============================] - 5s 110ms/step - loss: 0.2040 - accuracy: 0.9250 - val_loss: 0.4053 - val_accuracy: 0.8650
# Epoch 57/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.2099 - accuracy: 0.9312 - val_loss: 0.4348 - val_accuracy: 0.8550
# Epoch 58/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.1642 - accuracy: 0.9425 - val_loss: 0.4177 - val_accuracy: 0.8550
# Epoch 59/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1506 - accuracy: 0.9525 - val_loss: 0.4240 - val_accuracy: 0.8500
# Epoch 60/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1617 - accuracy: 0.9500 - val_loss: 0.4253 - val_accuracy: 0.8800
# Epoch 61/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1419 - accuracy: 0.9575 - val_loss: 0.4204 - val_accuracy: 0.8650
# Epoch 62/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1381 - accuracy: 0.9663 - val_loss: 0.4126 - val_accuracy: 0.8550
# Epoch 63/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1102 - accuracy: 0.9638 - val_loss: 0.4109 - val_accuracy: 0.8500
# Epoch 64/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.1362 - accuracy: 0.9563 - val_loss: 0.3977 - val_accuracy: 0.8650
# Epoch 65/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0946 - accuracy: 0.9675 - val_loss: 0.4082 - val_accuracy: 0.8550
# Epoch 66/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.1092 - accuracy: 0.9588 - val_loss: 0.4016 - val_accuracy: 0.8650
# Epoch 67/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0962 - accuracy: 0.9762 - val_loss: 0.4011 - val_accuracy: 0.8600
# Epoch 68/70
# 50/50 [==============================] - 5s 108ms/step - loss: 0.0798 - accuracy: 0.9688 - val_loss: 0.4318 - val_accuracy: 0.8600
# Epoch 69/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0983 - accuracy: 0.9688 - val_loss: 0.4320 - val_accuracy: 0.8650
# Epoch 70/70
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0767 - accuracy: 0.9787 - val_loss: 0.4274 - val_accuracy: 0.8550

# %%
# cross-validated accuracy for pre-trained model before training
print("Base model accuracy:", np.mean(base_model_acc_list))
# cross-validated accuracy before fine-tuning
print("Accuracy before fine-tuning:", np.mean(pre_trained_acc_list))
# cross-validated accuracy after fine-tuning
print("Final accuracy:", np.mean(final_acc_list))
# Out:
# Base model accuracy: 0.11200000047683716
# Accuracy before fine-tuning: 0.8289999961853027
# Final accuracy: 0.8670000076293946

# %%
# plot graph of cross-validated accuracies
acc = np.mean(history_map['accuracy'], axis=0)
val_acc = np.mean(history_map['val_accuracy'], axis=0)

plt.figure(1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.plot([no_epochs-1,no_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# plot graph of cross-validated losses
loss = np.mean(history_map['loss'], axis=0)
val_loss = np.mean(history_map['val_loss'], axis=0)

plt.figure(2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.plot([no_epochs-1,no_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
