# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# set path to FMD image directory
data_dir = pathlib.Path("image")

# total no. of images in FMD dataset
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 1000

# %%
# set batch size for training
batch_size = 16

# set dimensions to change images into for training
# 299x299 images is required for pre-trained models like Inception V3
img_height = 299
img_width = 299

# %%
# create dataset from the image directory
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*.jpg'), shuffle=False)
# shuffle the 1,000 images with the random seed value of 123 before training
list_ds = list_ds.shuffle(image_count, seed=123, reshuffle_each_iteration=False)

# %%
# get class names from the folder names in data_dir
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['fabric' 'foliage' 'glass' 'leather' 'metal' 'paper' 'plastic' 'stone'
#  'water' 'wood']

# %%
# split dataset into 5 equal sized parts for 5-fold cross validation
A = list_ds.shard(num_shards=5, index=0)
B = list_ds.shard(num_shards=5, index=1)
C = list_ds.shard(num_shards=5, index=2)
D = list_ds.shard(num_shards=5, index=3)
E = list_ds.shard(num_shards=5, index=4)

# %%
# check no. of samples in each partition is the same
print(A.cardinality().numpy())
print(B.cardinality().numpy())
print(C.cardinality().numpy())
print(D.cardinality().numpy())
print(E.cardinality().numpy())
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# prompt the tf.data runtime to tune the number of elements to prefetch dynamically at runtime
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# use the path of image to load the image into each partition of the dataset
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
A = A.map(process_path, num_parallel_calls=AUTOTUNE)
B = B.map(process_path, num_parallel_calls=AUTOTUNE)
C = C.map(process_path, num_parallel_calls=AUTOTUNE)
D = D.map(process_path, num_parallel_calls=AUTOTUNE)
E = E.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in A.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (299, 299, 3)
# Label:  1

# %%
# shuffle, batch, and prefetch the dataset
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
# map the dataset partitions to integers for building training/test sets during cross-validation
ds_fold_dict = {0:A, 1:B, 2:C, 3:D, 4:E}

# %%
# normalise the input values to the pre-trained model's required range of values
preprocess_input = keras.applications.inception_v3.preprocess_input

# %%
# set a low learning rate to avoid overfitting too quickly
base_learning_rate = 0.0001

# create the model to train using the pre-trained model as base model
def create_model(base_model):
  # generate additional training data from input training data by augmenting them using random flip, rotation & zoom
  data_augmentation = keras.Sequential(
    [
      layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                  input_shape=(img_height, 
                                                                img_width,
                                                                3)),
      layers.experimental.preprocessing.RandomRotation(0.1),
      layers.experimental.preprocessing.RandomZoom(0.1),
    ]
  )

  # average over the spatial locations to convert the features to a single vector per image
  global_average_layer = keras.layers.GlobalAveragePooling2D()
  # convert these features into a single prediction per image
  prediction_layer = keras.layers.Dense(10)

  # Build a model by chaining together the layers using the Keras Functional API.
  inputs = keras.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = preprocess_input(x)
  x = base_model(x, training=False) # use training=False as the base model contains a BatchNormalization layer
  x = global_average_layer(x)
  x = keras.layers.Dropout(0.2)(x) # add dropout to fully connected layer to reduce overfitting
  outputs = prediction_layer(x)
  model = keras.Model(inputs, outputs)
  optimizer = keras.optimizers.Adam(lr=base_learning_rate)
  loss= keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  # compile model with Adam optimizer with specified learning rate
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  model.summary()
  return model

# %%
no_epochs = 50
fine_tune_epochs = 20
total_epochs =  no_epochs + fine_tune_epochs
# Fine-tune from this layer onwards
fine_tune_at = 249

# %%
# store results to plot graphs and get cross-validated accuracies
history_map = {}
base_model_acc_list = []
pre_trained_acc_list = []
final_acc_list = []

# do 5-fold cross-validation
for i in range(5):
  print('fold', i + 1)
  temp_dict = ds_fold_dict.copy()
  # get test set for this iteration
  current_val_ds = temp_dict[i]

  # get training set for this iteration from remaining data samples
  del temp_dict[i]
  current_train_ds = None
  for ds_shard in temp_dict.values():
    if current_train_ds is None:
      current_train_ds = ds_shard
    else:
      current_train_ds = current_train_ds.concatenate(ds_shard)
  
  # configure both training and test sets to improve performance
  current_train_ds = configure_for_performance(current_train_ds)
  current_val_ds = configure_for_performance(current_val_ds)

  # get pre-trained model
  base_model = keras.applications.InceptionV3(include_top=False, input_shape=(img_height, img_width, 3))
  # don't train base model weights
  base_model.trainable = False

  # create a new model
  model = create_model(base_model)
  # get initial test accuracy
  base_model_acc_list.append(model.evaluate(current_val_ds)[1])
  # train for specified epochs
  history = model.fit(current_train_ds,
                    epochs=no_epochs,
                    validation_data=current_val_ds)
  
  # get test accuracy before fine-tuning
  pre_trained_acc_list.append(model.evaluate(current_val_ds)[1])

  # start fine-tuning by setting base model to be trainable
  base_model.trainable = True

  # Freeze all the layers before the `fine_tune_at` layer to only fine-tune top layer(s)
  for layer in base_model.layers[:fine_tune_at]:
    layer.trainable =  False

  # compile model again with RMSProp optimizer with even smaller learning rate to reduce overfitting
  optimizer = keras.optimizers.RMSprop(lr=base_learning_rate/10)
  loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  print('Fine-tuned model:')
  model.summary()

  # train fine-tuned model
  history_fine = model.fit(current_train_ds,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=current_val_ds)

  # save results
  if i == 0:
    history_map['accuracy'] = [history.history['accuracy'] + history_fine.history['accuracy']]
    history_map['val_accuracy'] = [history.history['val_accuracy'] + history_fine.history['val_accuracy']]
    history_map['loss'] = [history.history['loss'] + history_fine.history['loss']]
    history_map['val_loss'] = [history.history['val_loss'] + history_fine.history['val_loss']]
  else:
    history_map['accuracy'].append(history.history['accuracy'] + history_fine.history['accuracy'])
    history_map['val_accuracy'].append(history.history['val_accuracy'] + history_fine.history['val_accuracy'])
    history_map['loss'].append(history.history['loss'] + history_fine.history['loss'])
    history_map['val_loss'].append(history.history['val_loss'] + history_fine.history['val_loss'])
  
  # get final test accuracy by taking the max accuracy over the whole training due to potential overfitting at end of fine-tuning
  final_acc_list.append(np.amax(history.history['val_accuracy'] + history_fine.history['val_accuracy']))
# Out:
# s/step - loss: 0.5943 - accuracy: 0.8587 - val_loss: 0.7159 - val_accuracy: 0.8000
# Epoch 35/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5795 - accuracy: 0.8587 - val_loss: 0.7084 - val_accuracy: 0.8200
# Epoch 36/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5611 - accuracy: 0.8650 - val_loss: 0.7089 - val_accuracy: 0.8150
# Epoch 37/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5555 - accuracy: 0.8700 - val_loss: 0.6968 - val_accuracy: 0.8200
# Epoch 38/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.5519 - accuracy: 0.8662 - val_loss: 0.6851 - val_accuracy: 0.8150
# Epoch 39/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.5433 - accuracy: 0.8687 - val_loss: 0.6759 - val_accuracy: 0.8250
# Epoch 40/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.5337 - accuracy: 0.8737 - val_loss: 0.6704 - val_accuracy: 0.8100
# Epoch 41/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5138 - accuracy: 0.8763 - val_loss: 0.6775 - val_accuracy: 0.8100
# Epoch 42/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4985 - accuracy: 0.8838 - val_loss: 0.6544 - val_accuracy: 0.8200
# Epoch 43/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5053 - accuracy: 0.8888 - val_loss: 0.6588 - val_accuracy: 0.8150
# Epoch 44/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5018 - accuracy: 0.8813 - val_loss: 0.6505 - val_accuracy: 0.8200
# Epoch 45/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4610 - accuracy: 0.8913 - val_loss: 0.6546 - val_accuracy: 0.8150
# Epoch 46/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4801 - accuracy: 0.8838 - val_loss: 0.6412 - val_accuracy: 0.8200
# Epoch 47/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4917 - accuracy: 0.8675 - val_loss: 0.6378 - val_accuracy: 0.8200
# Epoch 48/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4579 - accuracy: 0.8888 - val_loss: 0.6406 - val_accuracy: 0.8150
# Epoch 49/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4693 - accuracy: 0.8863 - val_loss: 0.6289 - val_accuracy: 0.8200
# Epoch 50/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4382 - accuracy: 0.9025 - val_loss: 0.6307 - val_accuracy: 0.8150
# 13/13 [==============================] - 1s 40ms/step - loss: 0.6307 - accuracy: 0.8150
# Fine-tuned model:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_3 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 21,823,274
# Trainable params: 11,135,370
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 50/70
# 50/50 [==============================] - 5s 94ms/step - loss: 0.3981 - accuracy: 0.8875 - val_loss: 0.5336 - val_accuracy: 0.8400
# Epoch 51/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.2987 - accuracy: 0.9038 - val_loss: 0.5584 - val_accuracy: 0.8200
# Epoch 52/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.2400 - accuracy: 0.9375 - val_loss: 0.5325 - val_accuracy: 0.8300
# Epoch 53/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.2004 - accuracy: 0.9312 - val_loss: 0.5478 - val_accuracy: 0.8250
# Epoch 54/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.1627 - accuracy: 0.9500 - val_loss: 0.5427 - val_accuracy: 0.8400
# Epoch 55/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.1261 - accuracy: 0.9650 - val_loss: 0.6075 - val_accuracy: 0.8150
# Epoch 56/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.1004 - accuracy: 0.9712 - val_loss: 0.5673 - val_accuracy: 0.8400
# Epoch 57/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0744 - accuracy: 0.9762 - val_loss: 0.6195 - val_accuracy: 0.8350
# Epoch 58/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0773 - accuracy: 0.9725 - val_loss: 0.5996 - val_accuracy: 0.8650
# Epoch 59/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0578 - accuracy: 0.9862 - val_loss: 0.6135 - val_accuracy: 0.8400
# Epoch 60/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0445 - accuracy: 0.9875 - val_loss: 0.6158 - val_accuracy: 0.8450
# Epoch 61/70
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0328 - accuracy: 0.9912 - val_loss: 0.6543 - val_accuracy: 0.8650
# Epoch 62/70
# 50/50 [==============================] - 4s 73ms/step - loss: 0.0337 - accuracy: 0.9900 - val_loss: 0.6696 - val_accuracy: 0.8450
# Epoch 63/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0360 - accuracy: 0.9900 - val_loss: 0.7434 - val_accuracy: 0.8700
# Epoch 64/70
# 50/50 [==============================] - 4s 71ms/step - loss: 0.0319 - accuracy: 0.9912 - val_loss: 0.6553 - val_accuracy: 0.8750
# Epoch 65/70
# 50/50 [==============================] - 4s 71ms/step - loss: 0.0156 - accuracy: 0.9975 - val_loss: 0.6320 - val_accuracy: 0.8900
# Epoch 66/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0375 - accuracy: 0.9912 - val_loss: 0.7372 - val_accuracy: 0.8500
# Epoch 67/70
# 50/50 [==============================] - 4s 71ms/step - loss: 0.0239 - accuracy: 0.9937 - val_loss: 0.6516 - val_accuracy: 0.8650
# Epoch 68/70
# 50/50 [==============================] - 4s 71ms/step - loss: 0.0128 - accuracy: 0.9950 - val_loss: 0.6768 - val_accuracy: 0.8750
# Epoch 69/70
# 50/50 [==============================] - 4s 71ms/step - loss: 0.0125 - accuracy: 0.9975 - val_loss: 0.6836 - val_accuracy: 0.8750
# Epoch 70/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.7212 - val_accuracy: 0.8800
# fold 5
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 21,823,274
# Trainable params: 20,490
# Non-trainable params: 21,802,784
# _________________________________________________________________
# 13/13 [==============================] - 1s 40ms/step - loss: 2.4567 - accuracy: 0.1100
# Epoch 1/50
# 50/50 [==============================] - 3s 56ms/step - loss: 2.3783 - accuracy: 0.1425 - val_loss: 2.2183 - val_accuracy: 0.2250
# Epoch 2/50
# 50/50 [==============================] - 3s 56ms/step - loss: 2.1462 - accuracy: 0.2125 - val_loss: 2.0626 - val_accuracy: 0.3100
# Epoch 3/50
# 50/50 [==============================] - 3s 56ms/step - loss: 1.9800 - accuracy: 0.3113 - val_loss: 1.9256 - val_accuracy: 0.3800
# Epoch 4/50
# 50/50 [==============================] - 3s 56ms/step - loss: 1.8205 - accuracy: 0.3988 - val_loss: 1.8039 - val_accuracy: 0.4250
# Epoch 5/50
# 50/50 [==============================] - 3s 56ms/step - loss: 1.7038 - accuracy: 0.4875 - val_loss: 1.6930 - val_accuracy: 0.5250
# Epoch 6/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.5784 - accuracy: 0.5562 - val_loss: 1.5977 - val_accuracy: 0.5500
# Epoch 7/50
# 50/50 [==============================] - 3s 56ms/step - loss: 1.4626 - accuracy: 0.5962 - val_loss: 1.5091 - val_accuracy: 0.6000
# Epoch 8/50
# 50/50 [==============================] - 3s 56ms/step - loss: 1.3910 - accuracy: 0.5975 - val_loss: 1.4362 - val_accuracy: 0.6100
# Epoch 9/50
# 50/50 [==============================] - 3s 56ms/step - loss: 1.3024 - accuracy: 0.6562 - val_loss: 1.3753 - val_accuracy: 0.6250
# Epoch 10/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.2459 - accuracy: 0.6712 - val_loss: 1.3097 - val_accuracy: 0.6650
# Epoch 11/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1579 - accuracy: 0.6975 - val_loss: 1.2599 - val_accuracy: 0.6700
# Epoch 12/50
# 50/50 [==============================] - 3s 57ms/step - loss: 1.1212 - accuracy: 0.7025 - val_loss: 1.2212 - val_accuracy: 0.7000
# Epoch 13/50
# 50/50 [==============================] - 3s 58ms/step - loss: 1.0685 - accuracy: 0.7262 - val_loss: 1.1886 - val_accuracy: 0.7000
# Epoch 14/50
# 50/50 [==============================] - 3s 56ms/step - loss: 1.0102 - accuracy: 0.7538 - val_loss: 1.1364 - val_accuracy: 0.7350
# Epoch 15/50
# 50/50 [==============================] - 3s 57ms/step - loss: 0.9997 - accuracy: 0.7375 - val_loss: 1.0984 - val_accuracy: 0.7450
# Epoch 16/50
# 50/50 [==============================] - 3s 57ms/step - loss: 0.9420 - accuracy: 0.7862 - val_loss: 1.0703 - val_accuracy: 0.7500
# Epoch 17/50
# 50/50 [==============================] - 3s 58ms/step - loss: 0.9093 - accuracy: 0.7925 - val_loss: 1.0366 - val_accuracy: 0.7550
# Epoch 18/50
# 50/50 [==============================] - 3s 57ms/step - loss: 0.8969 - accuracy: 0.7775 - val_loss: 1.0191 - val_accuracy: 0.7700
# Epoch 19/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.8556 - accuracy: 0.7925 - val_loss: 0.9985 - val_accuracy: 0.7450
# Epoch 20/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.8414 - accuracy: 0.7800 - val_loss: 0.9781 - val_accuracy: 0.7600
# Epoch 21/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.8100 - accuracy: 0.7975 - val_loss: 0.9536 - val_accuracy: 0.7600
# Epoch 22/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.8038 - accuracy: 0.8075 - val_loss: 0.9324 - val_accuracy: 0.7650
# Epoch 23/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.7311 - accuracy: 0.8400 - val_loss: 0.9165 - val_accuracy: 0.7850
# Epoch 24/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.7399 - accuracy: 0.8163 - val_loss: 0.9124 - val_accuracy: 0.7600
# Epoch 25/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.7178 - accuracy: 0.8163 - val_loss: 0.8797 - val_accuracy: 0.7850
# Epoch 26/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.7002 - accuracy: 0.8338 - val_loss: 0.8700 - val_accuracy: 0.8000
# Epoch 27/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.6848 - accuracy: 0.8213 - val_loss: 0.8501 - val_accuracy: 0.7900
# Epoch 28/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.6570 - accuracy: 0.8487 - val_loss: 0.8449 - val_accuracy: 0.7800
# Epoch 29/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.6473 - accuracy: 0.8462 - val_loss: 0.8338 - val_accuracy: 0.7800
# Epoch 30/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.6440 - accuracy: 0.8388 - val_loss: 0.8259 - val_accuracy: 0.7900
# Epoch 31/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.6175 - accuracy: 0.8500 - val_loss: 0.8165 - val_accuracy: 0.7850
# Epoch 32/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.6076 - accuracy: 0.8500 - val_loss: 0.8124 - val_accuracy: 0.7850
# Epoch 33/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5738 - accuracy: 0.8637 - val_loss: 0.7908 - val_accuracy: 0.7950
# Epoch 34/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5828 - accuracy: 0.8675 - val_loss: 0.7804 - val_accuracy: 0.8000
# Epoch 35/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.5817 - accuracy: 0.8550 - val_loss: 0.7726 - val_accuracy: 0.7900
# Epoch 36/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5825 - accuracy: 0.8500 - val_loss: 0.7645 - val_accuracy: 0.8100
# Epoch 37/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5271 - accuracy: 0.8788 - val_loss: 0.7642 - val_accuracy: 0.8000
# Epoch 38/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5357 - accuracy: 0.8700 - val_loss: 0.7560 - val_accuracy: 0.8000
# Epoch 39/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.5244 - accuracy: 0.8712 - val_loss: 0.7422 - val_accuracy: 0.7850
# Epoch 40/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5284 - accuracy: 0.8562 - val_loss: 0.7395 - val_accuracy: 0.8000
# Epoch 41/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5159 - accuracy: 0.8687 - val_loss: 0.7292 - val_accuracy: 0.8150
# Epoch 42/50
# 50/50 [==============================] - 3s 55ms/step - loss: 0.5221 - accuracy: 0.8725 - val_loss: 0.7296 - val_accuracy: 0.7950
# Epoch 43/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.5071 - accuracy: 0.8725 - val_loss: 0.7189 - val_accuracy: 0.8050
# Epoch 44/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4979 - accuracy: 0.8838 - val_loss: 0.7306 - val_accuracy: 0.7900
# Epoch 45/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4850 - accuracy: 0.8863 - val_loss: 0.7085 - val_accuracy: 0.7950
# Epoch 46/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4879 - accuracy: 0.8800 - val_loss: 0.7105 - val_accuracy: 0.8050
# Epoch 47/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4714 - accuracy: 0.8788 - val_loss: 0.7050 - val_accuracy: 0.8100
# Epoch 48/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4512 - accuracy: 0.8963 - val_loss: 0.7053 - val_accuracy: 0.8050
# Epoch 49/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4493 - accuracy: 0.8825 - val_loss: 0.6966 - val_accuracy: 0.8050
# Epoch 50/50
# 50/50 [==============================] - 3s 56ms/step - loss: 0.4442 - accuracy: 0.8913 - val_loss: 0.6842 - val_accuracy: 0.8150
# 13/13 [==============================] - 0s 38ms/step - loss: 0.6842 - accuracy: 0.8150
# Fine-tuned model:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# inception_v3 (Functional)    (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 21,823,274
# Trainable params: 11,135,370
# Non-trainable params: 10,687,904
# _________________________________________________________________
# Epoch 50/70
# 50/50 [==============================] - 5s 91ms/step - loss: 0.3904 - accuracy: 0.8850 - val_loss: 0.6019 - val_accuracy: 0.8000
# Epoch 51/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.2931 - accuracy: 0.9062 - val_loss: 0.5790 - val_accuracy: 0.8150
# Epoch 52/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.2374 - accuracy: 0.9175 - val_loss: 0.5497 - val_accuracy: 0.7950
# Epoch 53/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.2005 - accuracy: 0.9438 - val_loss: 0.5695 - val_accuracy: 0.8000
# Epoch 54/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.1608 - accuracy: 0.9488 - val_loss: 0.5244 - val_accuracy: 0.8300
# Epoch 55/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.1169 - accuracy: 0.9625 - val_loss: 0.5392 - val_accuracy: 0.8250
# Epoch 56/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.1114 - accuracy: 0.9663 - val_loss: 0.5340 - val_accuracy: 0.8150
# Epoch 57/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0649 - accuracy: 0.9812 - val_loss: 0.5516 - val_accuracy: 0.8100
# Epoch 58/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0786 - accuracy: 0.9787 - val_loss: 0.5558 - val_accuracy: 0.8300
# Epoch 59/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0381 - accuracy: 0.9950 - val_loss: 0.5887 - val_accuracy: 0.8000
# Epoch 60/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0566 - accuracy: 0.9887 - val_loss: 0.5648 - val_accuracy: 0.8300
# Epoch 61/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0338 - accuracy: 0.9900 - val_loss: 0.6336 - val_accuracy: 0.7900
# Epoch 62/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0472 - accuracy: 0.9862 - val_loss: 0.5996 - val_accuracy: 0.8100
# Epoch 63/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0400 - accuracy: 0.9887 - val_loss: 0.6496 - val_accuracy: 0.8050
# Epoch 64/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0296 - accuracy: 0.9912 - val_loss: 0.6173 - val_accuracy: 0.8250
# Epoch 65/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.7255 - val_accuracy: 0.8000
# Epoch 66/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0180 - accuracy: 0.9975 - val_loss: 0.6677 - val_accuracy: 0.8250
# Epoch 67/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0321 - accuracy: 0.9912 - val_loss: 0.6374 - val_accuracy: 0.8100
# Epoch 68/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0225 - accuracy: 0.9912 - val_loss: 0.7457 - val_accuracy: 0.8150
# Epoch 69/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0201 - accuracy: 0.9962 - val_loss: 0.6951 - val_accuracy: 0.8150
# Epoch 70/70
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.7322 - val_accuracy: 0.8100

# %%
# cross-validated accuracy for pre-trained model before training
print("Base model accuracy:", np.mean(base_model_acc_list))
# cross-validated accuracy before fine-tuning
print("Accuracy before fine-tuning:", np.mean(pre_trained_acc_list))
# cross-validated accuracy after fine-tuning
print("Final accuracy:", np.mean(final_acc_list))
# Out:
# Base model accuracy: 0.08999999910593033
# Accuracy before fine-tuning: 0.8119999885559082
# Final accuracy: 0.8639999985694885

# %%
# plot graph of cross-validated accuracies
acc = np.mean(history_map['accuracy'], axis=0)
val_acc = np.mean(history_map['val_accuracy'], axis=0)

plt.figure(1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.plot([no_epochs-1,no_epochs-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# plot graph of cross-validated losses
loss = np.mean(history_map['loss'], axis=0)
val_loss = np.mean(history_map['val_loss'], axis=0)

plt.figure(2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.plot([no_epochs-1,no_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
