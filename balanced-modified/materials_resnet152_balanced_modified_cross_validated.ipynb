# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# set path to FMD image directory
data_dir = pathlib.Path("image")

# total no. of images in FMD dataset
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 1000

# %%
# set batch size for training
batch_size = 16

# set dimensions to change images into for training
# 299x299 images is used to train for consistency between different pre-trained models
img_height = 299
img_width = 299

# %%
# get class names from the folder names in data_dir
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
print(class_names)
# Out:
# ['fabric' 'foliage' 'glass' 'leather' 'metal' 'paper' 'plastic' 'stone'
#  'water' 'wood']

# %%
# create list containing the dataset for each class
ds_each_class = [tf.data.Dataset.list_files(str(data_dir/f'{class_name}/*.jpg'), shuffle=False) for class_name in class_names]

# shuffle the 100 images in each class with the random seed value of 123 before training
for index, ds in enumerate(ds_each_class):
  ds_each_class[index] = ds.shuffle(image_count//10, seed=123, reshuffle_each_iteration=False)

# %%
# display some samples from a class to verify each class dataset contains only the class images
for f in ds_each_class[0].take(10):
  print(f.numpy())

for f in ds_each_class[1].take(10):
  print(f.numpy())
# Out:
# b'image\\fabric\\fabric_moderate_037_new.jpg'
# b'image\\fabric\\fabric_moderate_004_new.jpg'
# b'image\\fabric\\fabric_moderate_008_new.jpg'
# b'image\\fabric\\fabric_object_003_new.jpg'
# b'image\\fabric\\fabric_object_017_new.jpg'
# b'image\\fabric\\fabric_object_001_new.jpg'
# b'image\\fabric\\fabric_moderate_032_new.jpg'
# b'image\\fabric\\fabric_moderate_030_new.jpg'
# b'image\\fabric\\fabric_moderate_038_new.jpg'
# b'image\\fabric\\fabric_object_009_new.jpg'
# b'image\\foliage\\foliage_final_037_new.jpg'
# b'image\\foliage\\foliage_final_004_new.jpg'
# b'image\\foliage\\foliage_final_008_new.jpg'
# b'image\\foliage\\foliage_final_053_new.jpg'
# b'image\\foliage\\foliage_final_067_new.jpg'
# b'image\\foliage\\foliage_final_051_new.jpg'
# b'image\\foliage\\foliage_final_032_new.jpg'
# b'image\\foliage\\foliage_final_030_new.jpg'
# b'image\\foliage\\foliage_final_038_new.jpg'
# b'image\\foliage\\foliage_final_059_new.jpg'

# %%
# split first class dataset into 5 equal sized partitions
# then for remaining classes' datasets do the same and add to corresponding partition
# for 5-fold cross validation
A = ds_each_class[0].shard(num_shards=5, index=0)
B = ds_each_class[0].shard(num_shards=5, index=1)
C = ds_each_class[0].shard(num_shards=5, index=2)
D = ds_each_class[0].shard(num_shards=5, index=3)
E = ds_each_class[0].shard(num_shards=5, index=4)
for i in range(1, 10):
  A = A.concatenate(ds_each_class[i].shard(num_shards=5, index=0))
  B = B.concatenate(ds_each_class[i].shard(num_shards=5, index=1))
  C = C.concatenate(ds_each_class[i].shard(num_shards=5, index=2))
  D = D.concatenate(ds_each_class[i].shard(num_shards=5, index=3))
  E = E.concatenate(ds_each_class[i].shard(num_shards=5, index=4))

# %%
# check no. of samples in each partition is the same
print(A.cardinality().numpy())
print(B.cardinality().numpy())
print(C.cardinality().numpy())
print(D.cardinality().numpy())
print(E.cardinality().numpy())
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  one_hot = parts[-2] == class_names
  # Integer encode the label
  return tf.argmax(one_hot)

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # resize the image to the desired size
  return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# prompt the tf.data runtime to tune the number of elements to prefetch dynamically at runtime
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# use the path of image to load the image into each partition of the dataset
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
A = A.map(process_path, num_parallel_calls=AUTOTUNE)
B = B.map(process_path, num_parallel_calls=AUTOTUNE)
C = C.map(process_path, num_parallel_calls=AUTOTUNE)
D = D.map(process_path, num_parallel_calls=AUTOTUNE)
E = E.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in A.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (299, 299, 3)
# Label:  0

# %%
# shuffle, batch, and prefetch the dataset
def configure_for_performance(ds):
  ds = ds.cache()
  ds = ds.shuffle(buffer_size=1000)
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
# map the dataset partitions to integers for building training/test sets during cross-validation
ds_fold_dict = {0:A, 1:B, 2:C, 3:D, 4:E}

# %%
# normalise the input values to the pre-trained model's required range of values
preprocess_input = keras.applications.resnet_v2.preprocess_input

# %%
# get pre-trained model
base_model = keras.applications.ResNet152V2(include_top=False, input_shape=(img_height, img_width, 3))

# %%
# don't train base model weights
base_model.trainable = False

# %%
base_model.summary()
# Out:
# 31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block31_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block31_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block31_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block31_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block31_out (Add)         (None, 19, 19, 1024) 0           conv4_block30_out[0][0]
#                                                                  conv4_block31_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block32_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block31_out[0][0]
# __________________________________________________________________________________________________
# conv4_block32_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block32_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block32_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block32_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block32_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block32_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block32_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block32_2_conv (Conv2D)   (None, 19, 19, 256)  589824      conv4_block32_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block32_2_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block32_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block32_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block32_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block32_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block32_out (Add)         (None, 19, 19, 1024) 0           conv4_block31_out[0][0]
#                                                                  conv4_block32_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block32_out[0][0]
# __________________________________________________________________________________________________
# conv4_block33_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block33_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block33_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block33_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block33_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block33_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_conv (Conv2D)   (None, 19, 19, 256)  589824      conv4_block33_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block33_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block33_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block33_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_out (Add)         (None, 19, 19, 1024) 0           conv4_block32_out[0][0]
#                                                                  conv4_block33_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block33_out[0][0]
# __________________________________________________________________________________________________
# conv4_block34_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block34_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block34_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block34_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block34_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block34_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_conv (Conv2D)   (None, 19, 19, 256)  589824      conv4_block34_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block34_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block34_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block34_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_out (Add)         (None, 19, 19, 1024) 0           conv4_block33_out[0][0]
#                                                                  conv4_block34_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block34_out[0][0]
# __________________________________________________________________________________________________
# conv4_block35_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block35_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block35_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block35_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block35_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block35_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_conv (Conv2D)   (None, 19, 19, 256)  589824      conv4_block35_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block35_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_relu (Activatio (None, 19, 19, 256)  0           conv4_block35_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_3_conv (Conv2D)   (None, 19, 19, 1024) 263168      conv4_block35_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_out (Add)         (None, 19, 19, 1024) 0           conv4_block34_out[0][0]
#                                                                  conv4_block35_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_preact_bn (BatchN (None, 19, 19, 1024) 4096        conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_preact_relu (Acti (None, 19, 19, 1024) 0           conv4_block36_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_conv (Conv2D)   (None, 19, 19, 256)  262144      conv4_block36_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_bn (BatchNormal (None, 19, 19, 256)  1024        conv4_block36_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_relu (Activatio (None, 19, 19, 256)  0           conv4_block36_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_pad (ZeroPaddin (None, 21, 21, 256)  0           conv4_block36_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_conv (Conv2D)   (None, 10, 10, 256)  589824      conv4_block36_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_bn (BatchNormal (None, 10, 10, 256)  1024        conv4_block36_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_relu (Activatio (None, 10, 10, 256)  0           conv4_block36_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 10, 10, 1024) 0           conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_3_conv (Conv2D)   (None, 10, 10, 1024) 263168      conv4_block36_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_out (Add)         (None, 10, 10, 1024) 0           max_pooling2d_2[0][0]
#                                                                  conv4_block36_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 10, 10, 1024) 4096        conv4_block36_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 10, 10, 1024) 0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 10, 10, 512)  524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 10, 10, 512)  0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 12, 12, 512)  0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 10, 10, 512)  2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 10, 10, 512)  0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 10, 10, 2048) 2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 10, 10, 2048) 0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 10, 10, 2048) 8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 10, 10, 2048) 0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 10, 10, 512)  1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 10, 10, 512)  0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 12, 12, 512)  0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 10, 10, 512)  2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 10, 10, 512)  0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 10, 10, 2048) 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 10, 10, 2048) 8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 10, 10, 2048) 0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 10, 10, 512)  1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 10, 10, 512)  0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 12, 12, 512)  0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 10, 10, 512)  2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 10, 10, 512)  2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 10, 10, 512)  0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 10, 10, 2048) 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 10, 10, 2048) 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 10, 10, 2048) 8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 10, 10, 2048) 0           post_bn[0][0]
# ==================================================================================================
# Total params: 58,331,648
# Trainable params: 0
# Non-trainable params: 58,331,648
# __________________________________________________________________________________________________

# %%
# set a low learning rate to avoid overfitting too quickly
base_learning_rate = 0.0001

# create the model to train using the pre-trained model as base model
def create_model():
  # generate additional training data from input training data by augmenting them using random flip, rotation & zoom
  data_augmentation = keras.Sequential(
    [
      layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                  input_shape=(img_height, 
                                                                img_width,
                                                                3)),
      layers.experimental.preprocessing.RandomRotation(0.1),
      layers.experimental.preprocessing.RandomZoom(0.1),
    ]
  )

  # average over the spatial locations to convert the features to a single vector per image
  global_average_layer = keras.layers.GlobalAveragePooling2D()
  # increase network depth by adding additional fully connected layer of size 128 with ReLU activation
  fully_connected_layer = keras.layers.Dense(128, activation='relu')
  # convert these features into a single prediction per image
  prediction_layer = keras.layers.Dense(10)

  # Build a model by chaining together the layers using the Keras Functional API.
  inputs = keras.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = preprocess_input(x)
  x = base_model(x, training=False) # use training=False as the base model contains a BatchNormalization layer
  x = global_average_layer(x)
  x = keras.layers.Dropout(0.2)(x) # add dropout to fully connected layer to reduce overfitting
  x = fully_connected_layer(x)
  x = keras.layers.Dropout(0.2)(x) # add dropout to fully connected layer to reduce overfitting
  outputs = prediction_layer(x)
  model = keras.Model(inputs, outputs)
  optimizer = keras.optimizers.Adam(lr=base_learning_rate)
  loss= keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  # compile model with Adam optimizer with specified learning rate
  model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
  model.summary()
  return model

# %%
no_epochs = 100

# %%
# store results to plot graphs and get cross-validated accuracies
history_map = {}
base_model_acc_list = []
final_acc_list = []

# do 5-fold cross-validation
for i in range(5):
  print('fold', i + 1)
  temp_dict = ds_fold_dict.copy()
  # get test set for this iteration
  current_val_ds = temp_dict[i]

  # get training set for this iteration from remaining data samples
  del temp_dict[i]
  current_train_ds = None
  for ds_shard in temp_dict.values():
    if current_train_ds is None:
      current_train_ds = ds_shard
    else:
      current_train_ds = current_train_ds.concatenate(ds_shard)
  
  # configure both training and test sets to improve performance
  current_train_ds = configure_for_performance(current_train_ds)
  current_val_ds = configure_for_performance(current_val_ds)

  # create a new model
  model = create_model()
  # get initial test accuracy
  base_model_acc_list.append(model.evaluate(current_val_ds)[1])
  # train for specified epochs
  history = model.fit(current_train_ds,
                    epochs=no_epochs,
                    validation_data=current_val_ds)
  
  # save results
  if i == 0:
    history_map['accuracy'] = [history.history['accuracy']]
    history_map['val_accuracy'] = [history.history['val_accuracy']]
    history_map['loss'] = [history.history['loss']]
    history_map['val_loss'] = [history.history['val_loss']]
  else:
    history_map['accuracy'].append(history.history['accuracy'])
    history_map['val_accuracy'].append(history.history['val_accuracy'])
    history_map['loss'].append(history.history['loss'])
    history_map['val_loss'].append(history.history['val_loss'])
  
  # get final test accuracy by taking the max accuracy over the whole training
  final_acc_list.append(np.amax(history.history['val_accuracy']))
# Out:
#  - loss: 0.0789 - accuracy: 0.9787 - val_loss: 0.4469 - val_accuracy: 0.8800
# Epoch 75/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0717 - accuracy: 0.9850 - val_loss: 0.4696 - val_accuracy: 0.8800
# Epoch 76/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0814 - accuracy: 0.9762 - val_loss: 0.4609 - val_accuracy: 0.8750
# Epoch 77/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.0665 - accuracy: 0.9887 - val_loss: 0.4635 - val_accuracy: 0.8750
# Epoch 78/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.0782 - accuracy: 0.9762 - val_loss: 0.4767 - val_accuracy: 0.8650
# Epoch 79/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0667 - accuracy: 0.9887 - val_loss: 0.4556 - val_accuracy: 0.8750
# Epoch 80/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0639 - accuracy: 0.9862 - val_loss: 0.4847 - val_accuracy: 0.8700
# Epoch 81/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.0732 - accuracy: 0.9737 - val_loss: 0.4751 - val_accuracy: 0.8750
# Epoch 82/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0741 - accuracy: 0.9725 - val_loss: 0.4920 - val_accuracy: 0.8650
# Epoch 83/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.0750 - accuracy: 0.9825 - val_loss: 0.4780 - val_accuracy: 0.8750
# Epoch 84/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.0640 - accuracy: 0.9825 - val_loss: 0.4792 - val_accuracy: 0.8600
# Epoch 85/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0685 - accuracy: 0.9825 - val_loss: 0.4671 - val_accuracy: 0.8650
# Epoch 86/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.0586 - accuracy: 0.9912 - val_loss: 0.4724 - val_accuracy: 0.8750
# Epoch 87/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0658 - accuracy: 0.9800 - val_loss: 0.4898 - val_accuracy: 0.8450
# Epoch 88/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0711 - accuracy: 0.9837 - val_loss: 0.4850 - val_accuracy: 0.8750
# Epoch 89/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.0561 - accuracy: 0.9925 - val_loss: 0.4820 - val_accuracy: 0.8700
# Epoch 90/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0558 - accuracy: 0.9862 - val_loss: 0.4885 - val_accuracy: 0.8650
# Epoch 91/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0744 - accuracy: 0.9837 - val_loss: 0.4896 - val_accuracy: 0.8700
# Epoch 92/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0530 - accuracy: 0.9900 - val_loss: 0.4976 - val_accuracy: 0.8700
# Epoch 93/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0592 - accuracy: 0.9825 - val_loss: 0.4966 - val_accuracy: 0.8650
# Epoch 94/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.0535 - accuracy: 0.9862 - val_loss: 0.4952 - val_accuracy: 0.8750
# Epoch 95/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0524 - accuracy: 0.9912 - val_loss: 0.4842 - val_accuracy: 0.8750
# Epoch 96/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.0548 - accuracy: 0.9850 - val_loss: 0.4899 - val_accuracy: 0.8650
# Epoch 97/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0683 - accuracy: 0.9787 - val_loss: 0.4683 - val_accuracy: 0.8550
# Epoch 98/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0489 - accuracy: 0.9925 - val_loss: 0.4959 - val_accuracy: 0.8700
# Epoch 99/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0522 - accuracy: 0.9875 - val_loss: 0.5066 - val_accuracy: 0.8650
# Epoch 100/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.0516 - accuracy: 0.9837 - val_loss: 0.4908 - val_accuracy: 0.8650
# fold 5
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 299, 299, 3)]     0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 299, 299, 3)       0
# _________________________________________________________________
# tf_op_layer_RealDiv_4 (Tenso [(None, 299, 299, 3)]     0
# _________________________________________________________________
# tf_op_layer_Sub_4 (TensorFlo [(None, 299, 299, 3)]     0
# _________________________________________________________________
# resnet152v2 (Functional)     (None, 10, 10, 2048)      58331648
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 58,595,210
# Trainable params: 263,562
# Non-trainable params: 58,331,648
# _________________________________________________________________
# 13/13 [==============================] - 1s 106ms/step - loss: 2.7634 - accuracy: 0.1150
# Epoch 1/100
# 50/50 [==============================] - 8s 159ms/step - loss: 2.3145 - accuracy: 0.2138 - val_loss: 1.9366 - val_accuracy: 0.2950
# Epoch 2/100
# 50/50 [==============================] - 8s 159ms/step - loss: 1.8169 - accuracy: 0.3700 - val_loss: 1.5524 - val_accuracy: 0.5450
# Epoch 3/100
# 50/50 [==============================] - 8s 159ms/step - loss: 1.4616 - accuracy: 0.5275 - val_loss: 1.2405 - val_accuracy: 0.6350
# Epoch 4/100
# 50/50 [==============================] - 8s 161ms/step - loss: 1.1450 - accuracy: 0.6488 - val_loss: 1.0321 - val_accuracy: 0.7000
# Epoch 5/100
# 50/50 [==============================] - 8s 160ms/step - loss: 1.0175 - accuracy: 0.6850 - val_loss: 0.8967 - val_accuracy: 0.7200
# Epoch 6/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.8740 - accuracy: 0.7300 - val_loss: 0.7949 - val_accuracy: 0.7550
# Epoch 7/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.7960 - accuracy: 0.7513 - val_loss: 0.7284 - val_accuracy: 0.7750
# Epoch 8/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.6977 - accuracy: 0.7950 - val_loss: 0.6797 - val_accuracy: 0.7750
# Epoch 9/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.6301 - accuracy: 0.7900 - val_loss: 0.6304 - val_accuracy: 0.8000
# Epoch 10/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.5594 - accuracy: 0.8313 - val_loss: 0.6036 - val_accuracy: 0.8050
# Epoch 11/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.5533 - accuracy: 0.8238 - val_loss: 0.5880 - val_accuracy: 0.8350
# Epoch 12/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.4857 - accuracy: 0.8425 - val_loss: 0.5580 - val_accuracy: 0.8350
# Epoch 13/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.5048 - accuracy: 0.8462 - val_loss: 0.5467 - val_accuracy: 0.8450
# Epoch 14/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.4380 - accuracy: 0.8612 - val_loss: 0.5350 - val_accuracy: 0.8450
# Epoch 15/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.4232 - accuracy: 0.8612 - val_loss: 0.5210 - val_accuracy: 0.8300
# Epoch 16/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.4173 - accuracy: 0.8637 - val_loss: 0.5136 - val_accuracy: 0.8400
# Epoch 17/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.3951 - accuracy: 0.8825 - val_loss: 0.5197 - val_accuracy: 0.8350
# Epoch 18/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.3794 - accuracy: 0.8838 - val_loss: 0.5030 - val_accuracy: 0.8350
# Epoch 19/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.3625 - accuracy: 0.8800 - val_loss: 0.4992 - val_accuracy: 0.8350
# Epoch 20/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.3590 - accuracy: 0.8950 - val_loss: 0.5010 - val_accuracy: 0.8300
# Epoch 21/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.3186 - accuracy: 0.8913 - val_loss: 0.4879 - val_accuracy: 0.8500
# Epoch 22/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.2914 - accuracy: 0.9125 - val_loss: 0.4914 - val_accuracy: 0.8550
# Epoch 23/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.3022 - accuracy: 0.9075 - val_loss: 0.4809 - val_accuracy: 0.8350
# Epoch 24/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.2929 - accuracy: 0.8988 - val_loss: 0.4751 - val_accuracy: 0.8500
# Epoch 25/100
# 50/50 [==============================] - 8s 159ms/step - loss: 0.2840 - accuracy: 0.8938 - val_loss: 0.4747 - val_accuracy: 0.8400
# Epoch 26/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.2562 - accuracy: 0.9200 - val_loss: 0.4839 - val_accuracy: 0.8400
# Epoch 27/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.2419 - accuracy: 0.9287 - val_loss: 0.4786 - val_accuracy: 0.8500
# Epoch 28/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.2495 - accuracy: 0.9212 - val_loss: 0.4786 - val_accuracy: 0.8450
# Epoch 29/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.2354 - accuracy: 0.9337 - val_loss: 0.4793 - val_accuracy: 0.8550
# Epoch 30/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.2235 - accuracy: 0.9350 - val_loss: 0.4951 - val_accuracy: 0.8500
# Epoch 31/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.2089 - accuracy: 0.9400 - val_loss: 0.4810 - val_accuracy: 0.8400
# Epoch 32/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.2155 - accuracy: 0.9350 - val_loss: 0.4720 - val_accuracy: 0.8400
# Epoch 33/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.2233 - accuracy: 0.9300 - val_loss: 0.4799 - val_accuracy: 0.8400
# Epoch 34/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.2075 - accuracy: 0.9425 - val_loss: 0.4610 - val_accuracy: 0.8550
# Epoch 35/100
# 50/50 [==============================] - 8s 157ms/step - loss: 0.1888 - accuracy: 0.9500 - val_loss: 0.4703 - val_accuracy: 0.8450
# Epoch 36/100
# 50/50 [==============================] - 8s 159ms/step - loss: 0.1928 - accuracy: 0.9438 - val_loss: 0.4649 - val_accuracy: 0.8500
# Epoch 37/100
# 50/50 [==============================] - 8s 164ms/step - loss: 0.1853 - accuracy: 0.9400 - val_loss: 0.4676 - val_accuracy: 0.8450
# Epoch 38/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1730 - accuracy: 0.9413 - val_loss: 0.4719 - val_accuracy: 0.8550
# Epoch 39/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1697 - accuracy: 0.9425 - val_loss: 0.4746 - val_accuracy: 0.8450
# Epoch 40/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1688 - accuracy: 0.9463 - val_loss: 0.4742 - val_accuracy: 0.8450
# Epoch 41/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1749 - accuracy: 0.9463 - val_loss: 0.4784 - val_accuracy: 0.8500
# Epoch 42/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1402 - accuracy: 0.9638 - val_loss: 0.4866 - val_accuracy: 0.8500
# Epoch 43/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1581 - accuracy: 0.9650 - val_loss: 0.4791 - val_accuracy: 0.8400
# Epoch 44/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1514 - accuracy: 0.9625 - val_loss: 0.4751 - val_accuracy: 0.8500
# Epoch 45/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1553 - accuracy: 0.9675 - val_loss: 0.4754 - val_accuracy: 0.8550
# Epoch 46/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1441 - accuracy: 0.9563 - val_loss: 0.4907 - val_accuracy: 0.8500
# Epoch 47/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1363 - accuracy: 0.9550 - val_loss: 0.4849 - val_accuracy: 0.8450
# Epoch 48/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1485 - accuracy: 0.9675 - val_loss: 0.4818 - val_accuracy: 0.8450
# Epoch 49/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1194 - accuracy: 0.9725 - val_loss: 0.4827 - val_accuracy: 0.8550
# Epoch 50/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1325 - accuracy: 0.9613 - val_loss: 0.4870 - val_accuracy: 0.8550
# Epoch 51/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1433 - accuracy: 0.9538 - val_loss: 0.4856 - val_accuracy: 0.8550
# Epoch 52/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1091 - accuracy: 0.9737 - val_loss: 0.4789 - val_accuracy: 0.8550
# Epoch 53/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1110 - accuracy: 0.9688 - val_loss: 0.4930 - val_accuracy: 0.8450
# Epoch 54/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1015 - accuracy: 0.9725 - val_loss: 0.4847 - val_accuracy: 0.8500
# Epoch 55/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1239 - accuracy: 0.9712 - val_loss: 0.4980 - val_accuracy: 0.8450
# Epoch 56/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1150 - accuracy: 0.9663 - val_loss: 0.4871 - val_accuracy: 0.8600
# Epoch 57/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.1160 - accuracy: 0.9762 - val_loss: 0.4760 - val_accuracy: 0.8450
# Epoch 58/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.1219 - accuracy: 0.9650 - val_loss: 0.4972 - val_accuracy: 0.8550
# Epoch 59/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1076 - accuracy: 0.9675 - val_loss: 0.4987 - val_accuracy: 0.8400
# Epoch 60/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.0825 - accuracy: 0.9812 - val_loss: 0.4952 - val_accuracy: 0.8500
# Epoch 61/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1091 - accuracy: 0.9675 - val_loss: 0.5121 - val_accuracy: 0.8250
# Epoch 62/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.1034 - accuracy: 0.9750 - val_loss: 0.4905 - val_accuracy: 0.8550
# Epoch 63/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.0899 - accuracy: 0.9825 - val_loss: 0.5021 - val_accuracy: 0.8400
# Epoch 64/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.0840 - accuracy: 0.9812 - val_loss: 0.5036 - val_accuracy: 0.8400
# Epoch 65/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.1051 - accuracy: 0.9688 - val_loss: 0.5040 - val_accuracy: 0.8550
# Epoch 66/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0841 - accuracy: 0.9825 - val_loss: 0.4976 - val_accuracy: 0.8400
# Epoch 67/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.0801 - accuracy: 0.9812 - val_loss: 0.4994 - val_accuracy: 0.8350
# Epoch 68/100
# 50/50 [==============================] - 8s 163ms/step - loss: 0.0923 - accuracy: 0.9737 - val_loss: 0.4892 - val_accuracy: 0.8500
# Epoch 69/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0915 - accuracy: 0.9750 - val_loss: 0.4927 - val_accuracy: 0.8500
# Epoch 70/100
# 50/50 [==============================] - 8s 162ms/step - loss: 0.0915 - accuracy: 0.9725 - val_loss: 0.4908 - val_accuracy: 0.8600
# Epoch 71/100
# 50/50 [==============================] - 8s 161ms/step - loss: 0.0881 - accuracy: 0.9737 - val_loss: 0.5050 - val_accuracy: 0.8650
# Epoch 72/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.0871 - accuracy: 0.9775 - val_loss: 0.4907 - val_accuracy: 0.8450
# Epoch 73/100
# 50/50 [==============================] - 8s 157ms/step - loss: 0.0790 - accuracy: 0.9775 - val_loss: 0.5014 - val_accuracy: 0.8550
# Epoch 74/100
# 50/50 [==============================] - 8s 153ms/step - loss: 0.0803 - accuracy: 0.9837 - val_loss: 0.4863 - val_accuracy: 0.8400
# Epoch 75/100
# 50/50 [==============================] - 8s 154ms/step - loss: 0.0627 - accuracy: 0.9862 - val_loss: 0.4950 - val_accuracy: 0.8450
# Epoch 76/100
# 50/50 [==============================] - 8s 155ms/step - loss: 0.0899 - accuracy: 0.9775 - val_loss: 0.4971 - val_accuracy: 0.8550
# Epoch 77/100
# 50/50 [==============================] - 8s 153ms/step - loss: 0.0759 - accuracy: 0.9825 - val_loss: 0.4920 - val_accuracy: 0.8500
# Epoch 78/100
# 50/50 [==============================] - 8s 155ms/step - loss: 0.0849 - accuracy: 0.9775 - val_loss: 0.4838 - val_accuracy: 0.8450
# Epoch 79/100
# 50/50 [==============================] - 8s 158ms/step - loss: 0.0774 - accuracy: 0.9825 - val_loss: 0.4880 - val_accuracy: 0.8500
# Epoch 80/100
# 50/50 [==============================] - 8s 154ms/step - loss: 0.0625 - accuracy: 0.9837 - val_loss: 0.4942 - val_accuracy: 0.8450
# Epoch 81/100
# 50/50 [==============================] - 8s 154ms/step - loss: 0.0703 - accuracy: 0.9850 - val_loss: 0.4959 - val_accuracy: 0.8500
# Epoch 82/100
# 50/50 [==============================] - 8s 156ms/step - loss: 0.0825 - accuracy: 0.9775 - val_loss: 0.4945 - val_accuracy: 0.8500
# Epoch 83/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.0565 - accuracy: 0.9862 - val_loss: 0.4983 - val_accuracy: 0.8500
# Epoch 84/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.0677 - accuracy: 0.9812 - val_loss: 0.4971 - val_accuracy: 0.8500
# Epoch 85/100
# 50/50 [==============================] - 8s 160ms/step - loss: 0.0662 - accuracy: 0.9887 - val_loss: 0.5064 - val_accuracy: 0.8600
# Epoch 86/100
# 50/50 [==============================] - 8s 156ms/step - loss: 0.0747 - accuracy: 0.9850 - val_loss: 0.5125 - val_accuracy: 0.8550
# Epoch 87/100
# 50/50 [==============================] - 8s 152ms/step - loss: 0.0617 - accuracy: 0.9862 - val_loss: 0.5159 - val_accuracy: 0.8500
# Epoch 88/100
# 50/50 [==============================] - 8s 154ms/step - loss: 0.0771 - accuracy: 0.9775 - val_loss: 0.5221 - val_accuracy: 0.8450
# Epoch 89/100
# 50/50 [==============================] - 8s 158ms/step - loss: 0.0801 - accuracy: 0.9787 - val_loss: 0.5192 - val_accuracy: 0.8600
# Epoch 90/100
# 50/50 [==============================] - 8s 157ms/step - loss: 0.0729 - accuracy: 0.9787 - val_loss: 0.5176 - val_accuracy: 0.8650
# Epoch 91/100
# 50/50 [==============================] - 8s 156ms/step - loss: 0.0565 - accuracy: 0.9900 - val_loss: 0.5109 - val_accuracy: 0.8500
# Epoch 92/100
# 50/50 [==============================] - 8s 157ms/step - loss: 0.0671 - accuracy: 0.9825 - val_loss: 0.5249 - val_accuracy: 0.8500
# Epoch 93/100
# 50/50 [==============================] - 8s 154ms/step - loss: 0.0488 - accuracy: 0.9925 - val_loss: 0.5196 - val_accuracy: 0.8550
# Epoch 94/100
# 50/50 [==============================] - 8s 153ms/step - loss: 0.0774 - accuracy: 0.9762 - val_loss: 0.5348 - val_accuracy: 0.8350
# Epoch 95/100
# 50/50 [==============================] - 8s 154ms/step - loss: 0.0602 - accuracy: 0.9862 - val_loss: 0.5233 - val_accuracy: 0.8450
# Epoch 96/100
# 50/50 [==============================] - 8s 157ms/step - loss: 0.0616 - accuracy: 0.9862 - val_loss: 0.5206 - val_accuracy: 0.8500
# Epoch 97/100
# 50/50 [==============================] - 8s 150ms/step - loss: 0.0498 - accuracy: 0.9862 - val_loss: 0.5316 - val_accuracy: 0.8450
# Epoch 98/100
# 50/50 [==============================] - 8s 155ms/step - loss: 0.0715 - accuracy: 0.9850 - val_loss: 0.5186 - val_accuracy: 0.8450
# Epoch 99/100
# 50/50 [==============================] - 8s 154ms/step - loss: 0.0411 - accuracy: 0.9925 - val_loss: 0.5157 - val_accuracy: 0.8550
# Epoch 100/100
# 50/50 [==============================] - 8s 154ms/step - loss: 0.0525 - accuracy: 0.9837 - val_loss: 0.5149 - val_accuracy: 0.8550

# %%
# cross-validated accuracy for pre-trained model before training
print("Base model accuracy:", np.mean(base_model_acc_list))
# cross-validated accuracy after training
print("Final accuracy:", np.mean(final_acc_list))
# Out:
# Base model accuracy: 0.08900000005960465
# Final accuracy: 0.8610000014305115

# %%
# plot graph of cross-validated accuracies
acc = np.mean(history_map['accuracy'], axis=0)
val_acc = np.mean(history_map['val_accuracy'], axis=0)

plt.figure(1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.show()

# %%
# plot graph of cross-validated losses
loss = np.mean(history_map['loss'], axis=0)
val_loss = np.mean(history_map['val_loss'], axis=0)

plt.figure(2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
